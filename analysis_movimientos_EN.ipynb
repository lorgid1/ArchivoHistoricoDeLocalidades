# %% [markdown]
# # Movimientos Table

# %% [markdown]
# This notebook contains an analysis made to the Movement table of the Historical Locality Archive of all the states of Mexico. It focuses on the column ORI_MODIF because this is the column that contains texts that explain the administrative modifications that the locality has gone through. The result of this notebook will be a table generated from the ORI_MODIF column that will serve to fill the continuity gaps present in the population table of the dataset (habitantes.csv).

# %% [markdown]
# ## Inported Libraries and Configurations

# %%
import os
import pandas as pd

# %% [markdown]
# ## Import data

# %%
# Define the types of columns
dtype_columnas = {
    'CLAVE' : 'int64',
    'CVE_GEOEST' : 'string',
    'INDICE' : 'int64',
    'NOM_LOC' : 'string',
    'NOM_MUN' : 'string',
    'CAT_POLI' : 'string',
    'CAT_ADMIVA'   : 'string',
    'ORI_MODIF' : 'string' 
}

# %%
# Import CSVs

movimientos = pd.read_csv('CSVs/movimientos.csv', dtype= dtype_columnas)

# %%
# General Info

#movimientos.dtypes                     # Types of columns
#movimientos.columns                    # Column names
#movimientos.info(show_counts=True)     # General info
#movimientos.head(3)

# %% [markdown]
# ## Analisis de todas las columnas exepto ORI_MODIF

# %%
# Columna CLAVE

#movimientos.CLAVE.is_unique        # Contains unique values

# %%
# CVE_GEOEST Column

#movimientos.CVE_GEOEST.is_unique                       # Does not contain unique values
#max(movimientos.CVE_GEOEST.value_counts())             # Max frequency of a value is 24
#min(movimientos.CVE_GEOEST.value_counts())             # Min frequency of a value is 1
#movimientos.CVE_GEOEST.value_counts()                  # Value Frecuency - Most repeated value is 300130002
#movimientos.CVE_GEOEST.value_counts().value_counts()   # Frequency repetition count

# %%
# INDICE Column (It is NOT a table index)

#movimientos.INDICE.is_unique                       # Does not contain unique values
#max(movimientos.INDICE.value_counts())             # Max frecuency of a value is 409446
#min(movimientos.INDICE.value_counts())             # Min frequency of a value is 1
#movimientos.INDICE.value_counts()                  # Value Frecuency - Most repeated value is 1 followed by 2

# %%
# NOM_LOC Column

#movimientos.NOM_LOC.is_unique                       # Does not contain unique values
#max(movimientos.NOM_LOC.value_counts())             # Max frecuency of a value is 9721
#min(movimientos.NOM_LOC.value_counts())             # Min frequency of a value is 1
#movimientos.NOM_LOC.value_counts()                  # Value frecuency
#movimientos.NOM_LOC.value_counts().value_counts()   # Frequency repetition count

# %%
# NOM_MUN Column

#movimientos.NOM_MUN.is_unique                       # Does not contain unique values
#max(movimientos.NOM_MUN.value_counts())             # Max frecuency of a value is 20739
#min(movimientos.NOM_MUN.value_counts())             # Min frequency of a value is 1
#movimientos.NOM_MUN.value_counts()                  # Value Frecuency - Most repeated value is Ensenada followed by Mexicalli
#len(movimientos[movimientos.NOM_MUN.isnull()])      # There are 34 null values
#movimientos[movimientos.NOM_MUN.isnull()].head(3)   # There are no null values in CVE_GEOEST so the Municipality can be deduced
#movimientos[movimientos.NOM_MUN.isnull()]['ORI_MODIF'].value_counts()
                                                     # The value of ORI_MODIF when NOM_MUN is null

# %%
# CAT_POLI Column

#movimientos.CAT_POLI.is_unique                       # Does not contain unique values
#max(movimientos.CAT_POLI.value_counts())             # Max frecuency of a value is 1590564
#min(movimientos.CAT_POLI.value_counts())             # Min frequency of a value is 1
#movimientos.CAT_POLI.value_counts()                  # Frecuency values - Most repeated value is Indefinida
#movimientos[movimientos.CAT_POLI.isnull()]           # There is a null value

# %%
# CAT_ADMIVA Column

#movimientos.CAT_ADMIVA.is_unique                   # Does not contain unique values
#max(movimientos.CAT_ADMIVA.value_counts())         # Max frecuency of a value is 6800
#min(movimientos.CAT_ADMIVA.value_counts())         # Min frequency of a value is 2
#movimientos.CAT_ADMIVA.value_counts()              # Value Frecuency - Most repeated value is Delegación
#movimientos['CAT_ADMIVA'].isnull().sum()           # There are 2_419_988 null values
#movimientos['CAT_ADMIVA'].notnull().sum()          # 20541 are not null
#movimientos[movimientos.CAT_ADMIVA.isin([' '])].head(5)  # 106 have a space character as a value

# %% [markdown]
# ## ORI_MODIF column analysis

# %% [markdown]
# ### General overview

# %%
# Columna ORI_MODIF

#movimientos.ORI_MODIF.is_unique                 # Does not contain unique values (values repeat themselves)
#movimientos.ORI_MODIF.nunique()                 # Contains 68794 unique values
#movimientos.ORI_MODIF.isnull().value_counts()   # There are no null values
#movimientos.ORI_MODIF.value_counts()            # Value Frecuency - Most repeated value is "Censo de 2020."

# %% [markdown]
# Data frame will be reducend only to column CLAVE and ORI_MODIF to make it less memory intensive.

# %%
# Reduce dataframe to CLAVE and ORI_MODIF columns
origen_modificacion = movimientos.loc[:,('CLAVE','ORI_MODIF')]

# Remove line jumps in ORI_MODIF
origen_modificacion.ORI_MODIF.replace('\r\n', ' ', regex=True, inplace=True)

# Trim the white spaces at the begining and end of the string
origen_modificacion.ORI_MODIF = origen_modificacion.ORI_MODIF.str.strip()

# %%
# Make a copy of original dataset to play with it
a_revisar = origen_modificacion.copy()

# %%
#a_revisar.shape                                        # 2440529 rows and 2 columns 
#origen_modificacion.ORI_MODIF.value_counts().count()   # 63_087 unique values (original)
#a_revisar.ORI_MODIF.value_counts().count()             # 63_087 unique values (the copy)

# %% [markdown]
# ### Spelling mistakes

# %% [markdown]
# There where typing mistakes in the process of digitalization. The detected words were added to individual lists of each specific word.

# %%
# Misspelling of the word censo
censo_ortografia = ['Ceso','Conso','Cenos','Cesno','Cense','Ceno',
                    'Censd','Cnso','Cneso','Censio','Cendo','Cemnso',
                    'Cemso', 'Enso', 'Ce nso']

# Cases to review of the word Censo
#a_revisar[a_revisar.ORI_MODIF.str.contains('Ce ')] # Se incluye
#a_revisar[a_revisar.ORI_MODIF.str.contains('Censó')].ORI_MODIF.to_list() # No se incluye

# # Misspelling of the word Conteo
conteo_ortografia = ['Conte','Centeo','COnteo','Comnteo']

# # Misspelling of the word Decreto
decreto_ortografia = ['Decreo','Decereto','Decreno','Decrero', 'decreto',
                      'Decrerto','Decrteo','Dedreto','Dercreto','Dto.']

# # Misspelling of the word Actualización
actualizacion_ortografia = ['Actuaización','Actualizacón', 'Actualizazión',
                            'Atualización', 'Actua ', 'Activación']

# Cases to review of the word Actualización
#a_revisar[a_revisar.ORI_MODIF.str.contains('Actua ')] # Se incluye
#a_revisar[a_revisar.ORI_MODIF.str.contains('Activación')] # Se incluye

# Case Bando only has one detected misspelling that can be included in the regular expresion
# [Bandpo]

# Misspelling of the word Oficio
oficio_ortografia = ['Ofiocio','Oficuio','Ofico']

# Misspelling of the word Aclaración
aclaracion_ortografia = ['Aclración','Aclaratoria']

# Cases to review of the word Aclaración
#a_revisar[a_revisar.ORI_MODIF.str.contains('Aclaratoria')] # It is included although it could be the word Declaratoria

# %% [markdown]
# ### Origin clasification

# %%
# Prescense of key words in rows

# Total records in ORI_MODIF
#a_revisar.ORI_MODIF.count()                               # 2_440_529 matches in total                                                 

# Case Censo
#a_revisar[a_revisar.ORI_MODIF.str.contains('[Cc]enso')]   # 1_755_017 matches
#a_revisar[a_revisar.ORI_MODIF.str.contains('|'.join(censo_ortografia))].count() # 36 matches

# Case Conteo
#a_revisar[a_revisar.ORI_MODIF.str.contains('[Cc]onteo')]  # 555_005 matches 
#a_revisar[a_revisar.ORI_MODIF.str.contains('|'.join(conteo_ortografia))] # 555_ 012 matches

# Case Decreto
#a_revisar[a_revisar.ORI_MODIF.str.contains('[Dd]ecreto')]  # 55_235 matches
#a_revisar[a_revisar.ORI_MODIF.str.contains('|'.join(decreto_ortografia))].count() # 21 matches


# Case Actualización Geoestadística
#a_revisar[a_revisar.ORI_MODIF.str.contains('[Aa]ctualizaci[oó]n')]  # 40_522 matches
#a_revisar[a_revisar.ORI_MODIF.str.contains('|'.join(actualizacion_ortografia))].count() # 18 matches

# Case Bando
#a_revisar[a_revisar.ORI_MODIF.str.contains('[Bb]and[op]')]  # 16_777 matches

# Case Ley
#a_revisar[a_revisar.ORI_MODIF.str.contains('[Ll]ey')]  #  9_478 matches

# Case Oficio
#a_revisar[a_revisar.ORI_MODIF.str.contains('[Oo]ficio')]  # 5855 matches
#a_revisar[a_revisar.ORI_MODIF.str.contains('|'.join(oficio_ortografia))].count() # 3 matches

# Case Periódico
#a_revisar[a_revisar.ORI_MODIF.str.contains('[Pp]eri[oó]dico')]  # 7_776 matches

# Case Aclaración
#a_revisar[a_revisar.ORI_MODIF.str.contains('[Aa]claraci[oó]n')]  # 400 matches
#a_revisar[a_revisar.ORI_MODIF.str.contains('|'.join(aclaracion_ortografia))].count() # 2 matches


# Case Constitución... Articulo 129 se junta aqui.. revisar
#a_revisar[a_revisar.ORI_MODIF.str.contains('(c|C)(onstitución)')] # 602 matches (Case that shares records with actualizacion)

# Case Reformas
#a_revisar[a_revisar.ORI_MODIF.str.contains('[Rr]eformas')]  # 389 matches


# Case Presidencial
#a_revisar[a_revisar.ORI_MODIF.str.contains('(P|p)(residencial)')]  # 306 matches

# Integración
#a_revisar[a_revisar.ORI_MODIF.str.contains('((l|L)ista|(i|I)ntegración)')]# 402 matches (Case that shares records with actualziacion)

# Case Sentencias
#a_revisar[a_revisar.ORI_MODIF.str.contains('[Ss]entencia')].count() # 17 matches

# Case Acuerdos
#a_revisar[a_revisar.ORI_MODIF.str.contains('[aA]cuerdo')].count()  # 35 matches

# Case Documento
#a_revisar[a_revisar.ORI_MODIF.str.contains('[dD]ocumento')].count()  # 36 matches

# Case Reglamento
#a_revisar[a_revisar.ORI_MODIF.str.contains('[rR]eglamento')].count() # 93 matches


# Case Equivalencia
#a_revisar[a_revisar.ORI_MODIF.str.contains('[eE]quivalencia')].count() # 36 matches

#Case Intercensal
#a_revisar[a_revisar.ORI_MODIF.str.contains('[iI]ntercensal')].count() # 45 matches

# Case Resolución
#a_revisar[a_revisar.ORI_MODIF.str.contains('[rR]esoluci[oó]n')] # 259 matches (Has many cases in common with resolucion presidencial)

# Case Inventario
#a_revisar[a_revisar.ORI_MODIF.str.contains('[iI]nventario')].count() # 8 matches


# Case Sindicatura
#a_revisar[a_revisar.ORI_MODIF.str.contains('(s|S)(indicatura)')] # 1 matches

# Case Cambio
#a_revisar[a_revisar.ORI_MODIF.str.contains('(C|c)(ambio)')] # 235947 matches (Intersects with many inportant ones including censo, decreto y actualizacion  )


#a_revisar[a_revisar.ORI_MODIF.str.contains('[Oo]axaca')] # 8020 matches (Intersects with conteo)

# %% [markdown]
# A grandes rasgos, las siguientes palabras clave se pueden utilizar para dividir los registros en diferentes tipos de origen. Algunas palabras se pueden generalizar en un solo tipo y existen traslapes que se tienen que analizar con mas cuidado. Las divisiones acontinuacion se utilizarán para dividir los registros y hacer análisis mas finos.

# %%
# Total de registros: 2440529, Total of unique values: 63087

# Case Censo
a_revisar = a_revisar[~a_revisar.ORI_MODIF.str.contains('[Cc]enso')]    # Remaining matches: 685512 
                                                                        # Remaining unique values: 40528
a_revisar = a_revisar[~a_revisar.ORI_MODIF.str.contains('|'.join(censo_ortografia))]    # Remaining matches: 685483
                                                                                        # Remaining unique values: 40502

# Case Conteo
a_revisar = a_revisar[~a_revisar.ORI_MODIF.str.contains('[Cc]onteo')]   # Remaining matches: 130486
                                                                        # Remaining unique values: 31775
a_revisar = a_revisar[~a_revisar.ORI_MODIF.str.contains('|'.join(conteo_ortografia))]   # Remaining matches: 130477
                                                                                        # Remaining unique values: 31769

# Case Decreto
a_revisar = a_revisar[~a_revisar.ORI_MODIF.str.contains('[Dd]ecreto')]      # Remaining matches: 76815
                                                                            # Remaining unique values: 14712
a_revisar = a_revisar[~a_revisar.ORI_MODIF.str.contains('|'.join(decreto_ortografia))]      # Remaining matches: 76805
                                                                                            # Remaining unique values: 14702

# Case Actualizacion Geoestadística
a_revisar = a_revisar[~a_revisar.ORI_MODIF.str.contains('[Aa]ctualizaci[oó]n')]     # Remaining matches: 36324
                                                                                    # Remaining unique values: 7619
a_revisar = a_revisar[~a_revisar.ORI_MODIF.str.contains('|'.join(actualizacion_ortografia))]    # Remaining matches: 36306
                                                                                                # Remaining unique values: 7606

# Case Bando
a_revisar = a_revisar[~a_revisar.ORI_MODIF.str.contains('[Bb]and[op]')]     # Remaining matches: 19533
                                                                            # Remaining unique values: 4631

# Case Ley
a_revisar = a_revisar[~a_revisar.ORI_MODIF.str.contains('[Ll]ey')]      # Remaining matches: 10670
                                                                        # Remaining unique values: 3214

# # Case oficio
a_revisar = a_revisar[~a_revisar.ORI_MODIF.str.contains('[Oo]ficio')]   # Remaining matches: 5434
                                                                        # Remaining unique values: 1323
a_revisar = a_revisar[~a_revisar.ORI_MODIF.str.contains('|'.join(oficio_ortografia))]   # Remaining matches: 5431
                                                                                        # Remaining unique values: 1320

# Case Periódico
a_revisar = a_revisar[~a_revisar.ORI_MODIF.str.contains('[Pp]eri[oó]dico')]     # Remaining matches: 4776
                                                                                # Remaining unique values: 941

# Case Aclaración
a_revisar = a_revisar[~a_revisar.ORI_MODIF.str.contains('[Aa]claraci[oó]n')]    # Remaining matches: 4402
                                                                                # Remaining unique values: 908
a_revisar = a_revisar[~a_revisar.ORI_MODIF.str.contains('|'.join(aclaracion_ortografia))]   # Remaining matches: 4400
                                                                                            # Remaining unique values: 906

# Case Reformas
a_revisar = a_revisar[~a_revisar.ORI_MODIF.str.contains('[Rr]eformas')]     # Remaining matches: 4132
                                                                            # Remaining unique values: 899

# Case Inventario 
a_revisar = a_revisar[~a_revisar.ORI_MODIF.str.contains('[iI]nventario')]   # Remaining matches: 4124
                                                                            # Remaining unique values: 896

# Case Sentencia
a_revisar = a_revisar[~a_revisar.ORI_MODIF.str.contains('[Ss]entencia')]    # Remaining matches: 4107
                                                                            # Remaining unique values: 879

# Case Reglamento
a_revisar = a_revisar[~a_revisar.ORI_MODIF.str.contains('[rR]eglamento')]   # Remaining matches: 4050
                                                                            # Remaining unique values: 861

# Case Intercensal
a_revisar = a_revisar[~a_revisar.ORI_MODIF.str.contains('[iI]ntercensal')]      # Remaining matches: 4012
                                                                                # Remaining unique values: 845

# Case Documento
a_revisar = a_revisar[~a_revisar.ORI_MODIF.str.contains('[dD]ocumento')]    # Remaining matches: 3977
                                                                            # Remaining unique values: 821

# Case Acuerdo
a_revisar = a_revisar[~a_revisar.ORI_MODIF.str.contains('[aA]cuerdo')]      # Remaining matches: 3946
                                                                            # Remaining unique values: 795

# Case Equivalencia
a_revisar = a_revisar[~a_revisar.ORI_MODIF.str.contains('[eE]quivalencia')]     # Remaining matches: 3910
                                                                                # Remaining unique values: 782

# Case Integración
a_revisar = a_revisar[~a_revisar.ORI_MODIF.str.contains('[lL]ista|[iI]ntegraci[oó]n')]      # Remaining matches: 3840
                                                                                            # Remaining unique values: 750

# Case Resolución ... se podria juntar con sentencia?
a_revisar = a_revisar[~a_revisar.ORI_MODIF.str.contains('[rR]esoluci[oó]n')]    # Remaining matches: 3533
                                                                                # Remaining unique values: 561

# Case Estado de Oaxaca
a_revisar = a_revisar[~a_revisar.ORI_MODIF.str.contains('[oO]axaca')]   # Remaining matches: 877
                                                                        # Remaining unique values: 426

# Case Constitución
a_revisar = a_revisar[~a_revisar.ORI_MODIF.str.contains('[Cc]onstituci[oó]n')]      # Remaining matches: 491
                                                                                    # Remaining unique values: 147

# %%
# Remaining records and unique value counts
registros_restantes = a_revisar.ORI_MODIF.count()
cantidad_valores_unicos = a_revisar.ORI_MODIF.value_counts().count()

print(f'Remaining matches: {registros_restantes}, Remaining unique values: {cantidad_valores_unicos}')
# Out:
# Registros restantes: 491, Cantidad de valores unicos: 147

# %% [markdown]
# The techniques in which key word detection was based on were the extraction of the records first word, first letter and specific words. The remaining unique 147 values that didn’t fit any of the selected keywords will be reviewed in a later stage with other individual records that will be accumulating in further analysis.

# %%
# First word list in remaining unique values

# Extract the first word in the strings of ORI_MODIF
primera_palabra = a_revisar.ORI_MODIF.str.extract(r'^([^\s]+)').value_counts()

# Resetear el indice de una tupla a solo la primera palabra
# Reset the index form a tuple to only the string
primera_palabra.index = primera_palabra.index.get_level_values(0)

# Remaining first words
#primera_palabra

# %%
# Remaining unique values
valores_unicos_restantes = a_revisar.ORI_MODIF.value_counts().index

# %%
# Explore the remaining unique values
#valores_unicos_restantes[0:20]

# %%
# Divide the remaining values by letter
primera_letra = 'C'

# Unique values that start with this specific letter
#a_revisar[a_revisar.ORI_MODIF.str.startswith(primera_letra)]

# First string words that start with this specific letter
#primera_palabra[primera_palabra.index.str.startswith(primera_letra)]

# %% [markdown]
# ## The diferent origin types

# %% [markdown]
# The diferent origin types that have been detected are as follows:
# * Census Events
# * Decrees
# * (...)

# %% [markdown]
# ### Census Events

# %% [markdown]
# The first orgin event to be analyzed is the Census Event. The vast majority of modifications have this origin. Of the total records of 2_440_529, only 130_477 remain after extracting those containing the words Census and Count. The two great types of census event are these two categories.

# %% [markdown]
# Within the Census category, the population type is the most common one, but there are also cases where the modification comes from an economic or from a buildings census. All events contain a temporary dimension, they were carried out in aspecific year. The first population census was carried out in the year 1900 and the most recent one is from the year 2020.

# %%
# Census

# %%
# Count

# %% [markdown]
# ## To be organized...

# %%
empieza_con_censo = origen_modificacion.loc[origen_modificacion.ORI_MODIF.str.match('^Censo')].ORI_MODIF

# %%
#empieza_con_censo.count()   #Hay diferencia de 14 con las que empiezan con censo seguidas de un espacio
#empieza_con_censo[~empieza_con_censo.str.match('^Censo de \d{4}')].count() # 3920 Registros que no siguen Censo de y 4 digitos
#empieza_con_censo[~empieza_con_censo.str.match('^Censo de \d{4}')].value_counts().count() # 330 valores unicos
#empieza_con_censo[~empieza_con_censo.str.match('^Censo de \d{4}')].value_counts()[:20]   # censo e edificios es el mas comun 
empieza_con_censo[(~empieza_con_censo.str.match('^Censo de \d{4}')) & 
                  (~empieza_con_censo.str.match('.+(edificios|Edificios|Económico)'))].value_counts()[160:180]
# Out:
# Censo de1930. Cambio de nombre del municipio. ...    1
# Censo de1930. Censó con la localidad Paso Plat...    1
# Censo de1930. Censó con la localidad Manuel Ma...    1
# Censo de1910. Cambio de categoría política.          1
# Censo 2010. Viene del municipio Villa de Cos (...    1
# Name: ORI_MODIF, dtype: Int64

# %%
origen_modificacion.loc[origen_modificacion.ORI_MODIF.str.match('^Censo de \d{4}')].value_counts()
# Out:
# CLAVE    ORI_MODIF                                          ORIGEN
# 4861341  Censo de 1960.                                     Censo     1
# 6481651  Censo de 1940. Cambio de nombre de localidad. ...  Censo     1
# 6481649  Censo de 1921.                                     Censo     1
# 6481648  Censo de 1910.                                     Censo     1
# 6481647  Censo de 1900.                                     Censo     1
#                                                                      ..
# 5692074  Censo de 1990.                                     Censo     1
# 5692072  Censo de 2000.                                     Censo     1
# 5692070  Censo de 2020.                                     Censo     1
# 5692069  Censo de 2010.                                     Censo     1
# 7301869  Censo de 2010.                                     Censo     1
# Length: 1749214, dtype: int64

# %%
origen_modificacion.ORI_MODIF.str.extract(r'^[^\d]*(\d{4})').value_counts()
# Out:
# 2010    283965
# 1995    280263
# 2000    278869
# 2020    275821
# 2005    274825
#          ...
# 1788         1
# 1787         1
# 1785         1
# 1781         1
# 9598         1
# Length: 671, dtype: int64

# %%
len(todo[todo.str.match(r'.+ctualizac.+')].value_counts())
# Out:
# 9021

# %%
# Solo los valores que actualizaron la cantidad de población por un evento censal
actualizacion_censal_pob = todo[todo.str.match(r'^(Censo de |Conteo de )\d{4}\.$')]

# %%
# Valores que no son actualizaciones censales de poblacion
otro = todo[~todo.str.match(r'^(Censo de |Conteo de )\d{4}\.$')]

# %%
actualizacion_censal_tipo = todo[todo.str.match(r'^(Censo de |Conteo de )\d{4}\..+')]

# %%
actualizacion_tipo = otro[~todo.str.match(r'^(Censo de |Conteo de )\d{4}\..+')]

# %%
(actualizacion_tipo.value_counts() < 2).value_counts()
# Out:
# True     28164
# False     7560
# Name: ORI_MODIF, dtype: Int64

# %%
actualizacion_censal_tipo.replace(r'^(Censo de |Conteo de )\d{4}\.?\s+', '',regex=True).value_counts()
#'^(Censo de |Conteo de )\d{4}\.', ''
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 actualizacion_censal_tipo.replace(r'^(Censo de |Conteo de )\d{4}\.?\s+', '',regex=True).value_counts()
#
# NameError: name 'actualizacion_censal_tipo' is not defined

# %%
# Comprobaciones
#actualizacion_censal_tipo.str.startswith(('Censo', 'Conteo')).value_counts()
# Out:
# True    870288
# Name: ORI_MODIF, dtype: Int64

# %%
# actualizacion_censal.value_counts()     # Sumandolos son los valores mas comunes de origen de modificacion.
# Out:
# Censo de 2020.     188742
# Censo de 2000.     178687
# Censo de 2010.     177892
# Conteo de 2005.    171106
# Conteo de 1995.    123676
# Censo de 1990.     108950
# Censo de 1980.      98520
# Censo de 1970.      76107
# Censo de 1960.      67008
# Censo de 1950.      60354
# Censo de 1940.      54146
# Censo de 1930.      36823
# Censo de 1900.      32516
# Censo de 1910.      30783
# Censo de 1921.      26596
# Censo de 1995.         27
# Censo de 1939.         22
# Censo de 2005.          9
# Conteo de 1990.         6
# Conteo de 1930.         2
# Conteo de 2000.         1
# Conteo de 1925.         1
# Conteo de 1940.         1
# Conteo de 1921.         1
# Name: ORI_MODIF, dtype: Int64

# %%
todo = movimientos[movimientos.ORI_MODIF.str.match(r'^(Censo de |Conteo de )\d{4}\.$')].ORI_MODIF.str.replace(r'\r\n', ' ')
actualizacion_censal = movimientos[movimientos.ORI_MODIF.str.match(r'^(Censo de |Conteo de )\d{4}\..+')].ORI_MODIF
#otros = movimientos[~movimientos.ORI_MODIF.str.match(r'^(Censo de |Conteo de )\d{4}\.$')].ORI_MODIF
# Out:
# C:\Users\Lorrain\AppData\Local\Temp\ipykernel_5516\2214415388.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   todo = movimientos[movimientos.ORI_MODIF.str.match(r'^(Censo de |Conteo de )\d{4}\.$')].ORI_MODIF.str.replace(r'\r\n', ' ')

# %%
actualizacion_censal.value_counts()
# Out:
# Censo de 2020.
# Localidad deshabitada.               86232
# Conteo de 2005.
# Localidad deshabitada.              72883
# Censo de 2010.
# Localidad deshabitada.               71913
# Censo de 2000.
# Localidad deshabitada.               50078
# Conteo de 1995.
# Localidad deshabitada.              44475
#                                                      ...
# Censo de 1950.
#
# Localidad  deshabitada.                1
# Conteo de 1995.
# Se fusiona a  Sabidos (0077)....        1
# Conteo de 1995.
# Cambio de nombre de localidad...        1
# Censo de 1980.
# Pasa al municipio El Higo (205...        1
# Censo de 2010.
# Viene del municipio Villa de C...        1
# Name: ORI_MODIF, Length: 32338, dtype: Int64

# %%
list(censal_mas_info.str.replace(r'\r\n', ' ').unique())
# Out:
# C:\Users\Lorrain\AppData\Local\Temp\ipykernel_5516\344913569.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   list(censal_mas_info.str.replace(r'\r\n', ' ').unique())
# ['Censo de 2020. Localidad deshabitada.',
#  'Censo de 2010. Localidad deshabitada.',
#  'Censo de 2010. Cambio de nombre de localidad.',
#  'Conteo de 2005. Localidad deshabitada.',
#  'Conteo de 2005. Localidad rehabilitada.',
#  'Conteo de 2005. Localidad fusionada a Baños la Cantera (0114).',
#  'Conteo de 2005. Cambio de nombre de localidad.',
#  'Conteo de 1995. Baja de localidad.',
#  'Censo de 2000. Localidad deshabitada.',
#  'Censo de 2010. Baja de localidad.',
#  'Censo de 2000. Cambio de nombre de localidad.',
#  'Censo de 2000. Baja de localidad.',
#  'Censo de 2000. Localidad rehabilitada.',
#  'Conteo de 1995. Cambio de nombre de localidad. Localidad con dos viviendas.',
#  'Censo de 2010. Localidad rehabilitada.',
#  'Conteo de 1995. Baja de localidad. Pertenece al Estado de Jalisco 14.',
#  'Conteo de 1995. Cambio de nombre de localidad.',
#  'Conteo de 1995. Localidad con una vivienda.',
#  'Conteo de 1995. Localidad de dos viviendas.',
#  'Conteo de 1995. Localidad con dos viviendas.',
#  'Censo de 2005. Localidad deshabitada.',
#  'Conteo de 1995. Localidad deshabitada.',
#  'Censo de 2010. Localidad rehabilitada. Cambio de nombre de localidad.',
#  'Conteo de 1995. Localidad rehabilitada.',
#  'Conteo de 1995. Localidad con una vivienda. Cambio de nombre de localidad.',
#  'Censo de 1990. Localidad con una vivienda.',
#  'Censo de 1990. Baja de localidad.',
#  'Censo de 1990. A partir de este evento cambia a la clave (010011094).',
#  'Conteo de 1995. Cambio de nombre de localidad. Localidad de una vivienda.',
#  'Censo de 1990. Cambio de nombre de localidad.',
#  'Censo de 1990. Localidad de dos viviendas.',
#  'Censo de 1990. Cambio de nombre de localidad. Localidad con una vivienda. A partir de este evento cambia a la clave (010011172).',
#  'Censo de 2010. Localidad deshabitada. Cambio de nombre de localidad',
#  'Censo de 1990. Localidad con dos viviendas.',
#  'Censo de 1990. Localidad rehabilitada. Cambio de nombre de localidad.',
#  'Censo de 2010. Cambio de nombre de localidad. Localidad deshabitada.',
#  'Censo de 1990. Pasa al municipio Aguascalientes 001 con clave 0724.',
#  'Censo de 1990. A partir de este evento cambia a la clave 010050275. Localidad rehabilitada.',
#  'Censo de 2000. Localidad rehabilitada. Cambio de nombre de localidad.',
#  'Censo de 2010. Se conurba a Aguascalientes (0001).',
#  'Censo de 1990. Cambio de nombre de localidad. Localidad con dos viviendas.',
#  'Conteo de 1995. Cambio de nombre de localidad. Localidad con una vivienda.',
#  'Censo de 1990. Localidad rehabilitada. Localidad con una vivienda.',
#  'Conteo de 1995. Localidad rehabilitada. Localidad con una vivienda.',
#  'Censo de 1980. Localidad rehabilitada.',
#  'Censo de 1990. Localidad de una vivienda.',
#  'Censo de 1980. Cambio de nombre de localidad.',
#  'Conteo de 1995. Cambio de nombre de localidad. Localidad de dos viviendas.',
#  'Censo de 1980. Baja de localidad.',
#  'Conteo de 1995. Se conurba a Ojocaliente 0055.',
#  'Censo de 1980. Hasta este evento estuvo registrada con clave (010010383).',
#  'Censo de 1990. Localidad rehabilitada.',
#  'Censo de 1990. A partir de este evento cambia a la clave 010090051.',
#  'Censo de 1970. Cambio de nombre de localidad. Cambio de categoría política.',
#  'Censo de 1990.Se conurba a Ojocaliente (0055).',
#  'Censo de 1980. Localidad rehabilitada. Cambio de nombre de localidad.',
#  'Censo de 1980. Cambio de nombre de localidad. Cambio de categoría política.',
#  'Conteo de 1995. Localidad de dos Viviendas.',
#  'Censo de 1990. Localidad rehabilitada. Localidad con dos viviendas.',
#  'Censo de 1980. Localidad rehabilitada. Cambio de categoría política.',
#  'Censo de 1990. Se conurba a Aguascalientes (0001).',
#  'Censo de 1990. Localidad deshabitada.',
#  'Censo de 1980. Hasta este evento estuvo registrada con clave (010010317).',
#  'Censo de 1980. Se conurba a Pabellón de Arteaga 0001.',
#  'Censo de 1970. Baja de localidad.',
#  'Censo de 1970. Cambio de nombre de localidad.',
#  'Conteo de 1995. ',
#  'Censo de 1970. Hasta este evento estuvo registrada con clave 010050094.',
#  'Censo de 1990. A partir de este evento cambia a la clave (010011112). Localidad con dos viviendas.',
#  'Censo de 1980. Cambio de categoría política.',
#  'Conteo de 1995. Localidad rehabilitada. Localidad con dos viviendas.',
#  'Censo de 2000. Cambio de nombre de localidad. Localidad deshabitada.',
#  'Censo de 1970. Hasta este evento estuvo registrada con clave 010090007.',
#  'Censo de 2010. Localidad deshabitada. Cambio de nombre de localidad.',
#  'Censo de 1990. A partir de este evento cambia a la clave (010010664).',
#  'Censo de 1990. Cambio de nombre de localidad. Localidad de una vivienda.',
#  'Censo de 1990. Se conurba a Rincón de Romos 0001.',
#  'Conteo de 1995. A partir de este evento cambia a la clave 010030386. Cambio de nombre de localidad.',
#  'Censo de 1980. Hasta este evento estuvo registrada con clave (010010425).',
#  'Censo de 1990.  Localidad rehabilitada.',
#  'Censo de 1960. Cambio de nombre de localidad.',
#  'Censo de 1960. Localidad deshabitada.',
#  'Conteo de 1995. Localidad rehabilitada. Cambio de nombre de localidad. Localidad con una vivienda.',
#  'Censo de 1970. Localidad rehabilitada.',
#  'Censo de 1980. Hasta este evento estuvo registrada con clave 010030075.',
#  'Censo de 1990. Se fusiona a Los Ramírez 0076.',
#  'Censo de 2000. Localidad deshabitada. Localidad rehabilitada.',
#  'Censo de 1960. Cambio de nombre de localidad. Localidad deshabitada.',
#  'Censo de 1960. Localidad con una vivienda. Localidad deshabitada.',
#  'Censo de 1960. Cambio de nombre de localidad. Cambio de categoría política.',
#  'Censo de 1990. Localidad con dos viviendas. A partir de este evento cambia a la clave 010050279.',
#  'Censo de 1980. Hasta este evento estuvo registrada con clave (010010644).',
#  'Censo de 1990. Localidad rehabilitada. Cambio de nombre de localidad. Localidad con una vivienda.',
#  'Conteo de 1995. Localidad de dos viviendas. Localidad Rehabilitada.',
#  'Censo de 1990. A partir de este evento cambia a la clave (010011025).',
#  'Censo de 1960. Cambio de categoría política.',
#  'Censo de 1950. Cambio de nombre de localidad. Cambio de categoría política.',
#  'Censo de 1990. Localidad rehabilitada. Localidad de una vivienda.',
#  'Censo de 1950. Cambio de nombre de localidad.',
#  'Censo de 1980. Cambio de categoría política. Hasta este evento estuvo registrada con clave (010010662).',
#  'Censo de 1950. Localidad deshabitada.',
#  'Censo de 1950. Baja de localidad.',
#  'Conteo de 1995. Localidad con Una vivienda.',
#  'Conteo de 1995. Localidad de una vivienda.',
#  'Censo de 1950. Cambio de categoría política.',
#  'Censo de 1970. Localidad rehabilitada. Cambio de nombre de localidad.',
#  'Conteo de 2005. Localidad rehabilitada. Cambio de nombre de localidad.',
#  'Censo de 2010. Localidad conurbada a Jesús María 0001.',
#  'Censo de 1950. Cambio de nombre de localidad. Cambio de Categoría Política.',
#  'Censo de 2010. Localidad deshabitada.                  Cambio de nombre de localidad.     Se fusiona a  El Moro (0402).',
#  'Censo de 1990. A partir de este evento cambia a la clave 010050261.',
#  'Censo de 1970. Localidad deshabitada.',
#  'Censo de 2010.  Localidad deshabitada.',
#  'Conteo de 2005. Baja de localidad.',
#  'Censo de 1990. Cambio de nombre de localidad. Localidad con una vivienda.',
#  'Censo de 1960. Localidad rehabilitada.',
#  'Censo de 1990. Se conurba a Aguascalientes 0001.',
#  'Censo de 1950. Localidad rehabilitada.',
#  'Censo de 1950. Censada con la localidad La Tinaja.',
#  'Censo de 1960. Baja de localidad.',
#  'Censo de 2010. Se fusiona a El Bramadero (0611).',
#  'Censo de 1950. Hasta este evento estuvo registrada con clave 010050138.',
#  'Censo de 2010. Localidad conurbada a Rincón de Romos 0001.',
#  'Censo de 1940. Cambio de nombre de localidad.',
#  'Censo de 1990. Se conurba a Las Cuevas 0005.',
#  'Censo de 2010. Localidad fusionada a Crucero a San José de Gracia (Ejido Progreso) 0352.',
#  'Conteo de 2005. Localidad de una vivienda.',
#  'Censo de 2010. Localidad fusionada a Planta Chinoin 0142.',
#  'Censo de 2010. Localidad deshabitada. ',
#  'Censo de 1960.               Localidad deshabitada.',
#  'Censo de 2010. Localidad deshabitada ',
#  'Censo de 1990. A partir de este evento cambia a la clave (010010678).',
#  'Censo de 2010. Se fusiona a Barandales de San José (0519).',
#  'Censo de 1990. Cambio de nombre de localidad. A partir de este evento cambia a la clave (010010903).',
#  'Censo de 1990. Localidad rehabilitada. Cambio de nombre de localidad. Localidad con dos viviendas.',
#  'Censo de 2010. Pasa al municipio 001 con clave de localidad 2412.',
#  'Censo de 1970. Cambio de nombre de localidad. Cambio de Categoría Política.',
#  'Censo de 1940. Localidad deshabitada.',
#  'Censo de 2010. Se fusiona a Carboneras 0008.',
#  'Censo de 1940. Baja de localidad.',
#  'Censo de 2000. A partir de este evento cambia a la clave 010020213.',
#  'Censo de 1970. Se conurba a Calvillo (0001). ',
#  'Censo de 1960. Localidad rehabilitada. Localidad deshabitada.',
#  'Censo de 1960. Localidad deshabitada. Localidad rehabilitada.',
#  'Conteo de 2005. Localidad fusionada a Peña Azul 0423.',
#  'Censo de 1980. Localidad deshabitada.',
#  'Censo de 1980. Hasta este evento estuvo registrada con clave 010050075.',
#  'Censo de 1930. Cambio de nombre de localidad. Cambio de categoría política.',
#  'Censo de 1990. Localidad rehabilitada. Localidad con una vivienda. A partir de este evento cambia a la clave (010011092).',
#  'Censo de 1930. Cambio de nombre de localidad.',
#  'Censo de 1990. Localidad rehabilitada. Localidad de una vivienda. Localidad deshabitada. Cambio de nombre de localidad.',
#  'Censo de 2010. Localidad Rehabilitada.',
#  'Conteo de 1995. Hasta este evento estuvo registrada con clave 010020057. Localidad rehabilitada. Cambio de nombre de localidad. Localidad de dos viviendas.',
#  'Censo de 1930. Localidad deshabitada.',
#  'Censo de 2010. Localidad deshabitada  ',
#  'Censo de 1980. Hasta este evento estuvo registrada con clave (010010103).',
#  'Censo de 1990. A partir de este evento cambia a la clave (010010815).',
#  'Censo de 1980. Localidad rehabilitada. Localidad con una vivienda.',
#  'Censo de 1980. Se conurba a Calvillo 0001. ',
#  'Censo de 1930. Baja de localidad.',
#  'Censo de 1970. Hasta este evento estuvo registrada con clave (010010299).',
#  'Censo de 2010. Se conurba a Jesús María 0001.',
#  'Censo de 2010. Localidad deshabitada',
#  'Conteo de 2005. ',
#  'Censo de 1970. Cambio de categoría política.',
#  'Censo de 2010.  Localidad fusionada a Santa Clara (Las Mieleras) 0100.',
#  'Censo de 1990. Cambio de nombre de localidad. Localidad de dos viviendas.',
#  'Censo de 1930. Cambio de nombre de localidad. Localidad deshabitada.',
#  'Censo de 2010. Pasa al municipio Tepezalá 009 con clave 0160.',
#  'Censo de 1930. Localidad deshabitada. Localidad rehabilitada.',
#  'Censo de 1980.                   Baja de Localidad.',
#  'Censo de 2010. Localidad fusionada a San Luis de Letras 0040.',
#  'Censo de 2010. Localidad fusionada a Ninguno 0387.',
#  'Censo de 2010. Se fusiona a ninguno 0387.',
#  'Censo de 2010. Localidad fusionada a El Encino 0173.',
#  'Censo de 2000. Localidad rehabilitada. Localidad deshabitada. Cambio de nombre de localidad.',
#  'Censo de 2010. Localidad fusionada a El Pedregal 0236.',
#  'Censo de 1940. Localidad deshabitada. Cambio de nombre de localidad.',
#  'Censo de 2010. Localidad fusionada a Mexiquito 0101.',
#  'Censo de 2010. Se conurba a Pabellón de Hidalgo 0030.',
#  'Censo de 2010. Localidad fusionada a Sector Agropecuario de la Escuela Secundaria Técnica Numero 11 0372.',
#  'Censo de 2010. Localidad rehabilitada. ',
#  'Censo de 2000. Se fusiona a Fracc. Campestre San Carlos 0233.',
#  'Censo de 1990. Localidad con una vivienda. Localidad deshabitada.',
#  'Censo de 2000. Localidad de una vivienda.',
#  'Conteo de 2005. Localidad  deshabitada.',
#  'Censo de 2010. Localidad deshabitada.  ',
#  'Censo de 1970. Localidad rehabilitada. Cambio de nombre de localidad. Cambio de categoría política.',
#  'Censo de 1960. Localidad rehabilitada. Cambio de nombre de localidad.',
#  'Censo de 1930. Localidad rehabilitada.',
#  'Censo de 2020. ',
#  'Censo de 1980. Localidad rehabilitada. Cambio de categoría política. Localidad deshabitada.',
#  'Censo de 2010. Se conurba a Pocitos (1025).',
#  'Censo de 2010. Localidad conurbada a Aguascalientes (0001).',
#  'Censo de 2010. Localidad conurbada a Tepezalá 0001.',
#  'Censo de 2010. Se fusiona a El Filso (2065).',
#  'Censo de 2010. Se fusiona a El Refugio Número Dos [Rancho] 2173.',
#  'Censo de 2010. Baja de Localidad.',
#  'Censo de 2010. Localidad fusionada a El Filso (2065).',
#  'Censo de 2010.              ',
#  'Censo de 1921. Cambio de categoría política.',
#  'Censo de 1921. Cambio de nombre de localidad.',
#  'Censo de 2010.  Localidad deshabitada',
#  'Censo de 2010. Localidad fusionada a Sector Noria Blanca 0239.',
#  'Censo de 1930. Localidad rehabilitada. Cambio de nombre de localidad. Localidad deshabitada.',
#  'Conteo de 2005. Localidad deshabitada. ',
#  'Censo de 1990. Se conurba al municipio (011) San Francisco de los Romo localidad (0001).',
#  'Conteo de 2005. Localidad deshabitada ',
#  'Conteo de 1995.            Localidad de dos viviendas.',
#  'Conteo de 2005. Se fusiona a Pabellón de Arteaga 0001.',
#  'Censo de 1921. Baja de localidad.',
#  'Conteo de 1995. Localidad rehabilitada. Cambio de nombre de localidad.',
#  'Conteo de 2005. Localidad deshabitada   ',
#  'Conteo de 1995. Pasa al municipio Rincón de Romos 007 con clave 0303.',
#  'Conteo de 1995. Localidad rehabilitada. Localidad de dos viviendas.',
#  'Conteo de 1995. Pasa al municipio Rincón de Romos 007 con clave 0361.',
#  'Conteo de 1995. Pasa al municipio Rincón de Romos 007 con clave 0320.',
#  'Conteo de 2005. Localidad deshabitada  ',
#  'Conteo de 1995.  Localidad deshabitada.',
#  'Censo de 1990. Cambio de nombre de localidad. A partir de este evento cambia a la clave (010011118).',
#  'Conteo de 2005. Localidad deshabitada',
#  'Censo de 1990. A partir de este evento cambia a la clave (010011102).',
#  'Censo de 1970. Viene del municipio Asientos (002).',
#  'Censo de 1970. Localidad rehabilitada. Cambio de categoría política.',
#  'Censo de 1970. Viene del municipio Aguascalientes (001).',
#  'Censo de 1921. Cambio de nombre de localidad. Cambio de categoría política.',
#  'Censo de 2010. Localidad conurbada a Palo Alto 0001.',
#  'Censo de 1940. Localidad rehabilitada.',
#  'Censo de 1990. Pasa al municipio San Francisco de los Romo (011) con clave (0052). Decreto No. 162 del 30 de enero de 1992.',
#  'Censo de 2000. Localidad deshabitada. Cambio de nombre de localidad.',
#  'Censo de 1990. Cambio de nombre de localidad. Localidad rehabilitada. Localidad con una vivienda.',
#  'Conteo de 2010. Localidad deshabitada',
#  'Censo de 2000.                              Se fusiona a Granja San José (0055).',
#  'Conteo de 1995. Localidad rehabilitada. Localidad de una vivienda.',
#  'Censo de 2010. Se fusiona a San Cristóbal (1085).',
#  'Censo de 1990. Cambio de nombre de localidad. A partir de este evento cambia a la clave (010010919).',
#  'Conteo de 1995. Se conurba a Pabellón de Hidalgo 0030.',
#  'Censo de 2010. Se fusiona a Licenciado Adolfo López Mateos (0259).',
#  'Conteo de 2005. Localidad deshabitada. Cambio de nombre de localidad.',
#  'Censo de 1980. Baja de localidad',
#  'Censo de 2010. Localidad rehabilitada. Cambio de nombre de localidad. Localidad deshabitada.  ',
#  'Censo de 1980. Hasta este evento estuvo registrada con clave (010010118).',
#  'Censo de 1921. Localidad deshabitada.',
#  'Censo de 2010. Localidad fusionada a Santa Rita 0049.',
#  'Conteo de 1995. Cambio de nombre de localidad. Localidad deshabitada.',
#  'Conteo de 1995. Baja de localidad. Sin Viviendas.',
#  'Censo de 1980. Se fusiona a Emiliano Zapata 0007.',
#  'Censo de 1990. Cambio de nombre de localidad. A partir de este evento cambia a la clave (010010686).',
#  'Censo de 1990. Pasa al municipio Pabellón de Arteaga (006) con clave (0264).',
#  'Conteo de 2005. Localidad conurbada a Jesús María 0001.',
#  'Censo de 2005. Localidad deshabitada',
#  'Conteo de 1995. Pasa al municipio Rincón de Romos 007 con clave 0278.',
#  'Censo de 1921. Localidad rehabilitada. Cambio de categoría política.',
#  'Censo de 1990. Cambio de nombre de localidad. Localidad deshabitada.',
#  'Conteo de 1995. Pasa al municipio Rincón de Romos 007 con clave 0288.',
#  'Censo de 1960. Localidad deshabitada',
#  'Censo de 1930. Localidad deshabitada. Localidad rehabilitada. Cambio de nombre de localidad.',
#  'Conteo de 2005. Se fusiona a Chichihuas (0404).',
#  'Conteo de 1995. Localidad rehabilitada. Cambio de nombre de localidad. Localidad de una vivienda.',
#  'Censo de 2000. Se conurba a Jesús María 0001.',
#  'Censo de 1910. Cambio de nombre de localidad.',
#  'Censo de 1910. Cambio de nombre de localidad. Cambio de categoría política.',
#  'Censo de 1910. Baja de localidad.',
#  'Censo de 1940. Cambio de nombre de localidad. Cambio de categoría política.',
#  'Censo de 1990. Se conurba a Jesús Gómez Portugal (0041).',
#  'Censo de 1990. Se conurba a San Francisco de los Romo (0001).',
#  'Censo de 1980. Hasta este evento estuvo registrada con clave (010010346).',
#  'Censo de 1990. Cambio de nombre de localidad. Decreto No. 162 del 30 de enero de 1992. Pasa al municipio El Llano (010) con clave (0104).',
#  'Censo de 1990. Localidad con una vivienda. Cambio de nombre de localidad.',
#  'Conteo de 1995. Localidad con dos viviendas. Cambio de nombre de localidad.',
#  'Censo de 1980. Cambio de nombre de localidad. Cambio de categoría política. Hasta este evento estuvo registrada con clave (010010158).',
#  'Censo de 1990. Localidad con una vivienda. A partir de este evento cambia a la clave 010011015.',
#  'Censo de 1990. A partir de este evento cambia a la clave (010011027).',
#  'Conteo de 1995. Baja de localidad. Ruinas.',
#  'Censo de 1990. Localidad con una vivienda. A partir de este evento cambia a la clave (010011040).',
#  'Conteo de 1995. Baja de localidad. Es parte de la localidad Cables de Arellano.',
#  'Censo de 1990. Localidad con una vivienda. A partir de este evento cambia a la clave (010011072).',
#  'Conteo de 1995. Baja de localidad. Vivienda en Ruinas.',
#  'Censo de 1990. Cambio de nombre de localidad. A partir de este evento cambia a la clave (010011075).',
#  'Censo de 1990. A partir de este evento cambia a la clave (010011076).',
#  'Censo de 1990. A partir de este evento cambia a la clave (010011078).',
#  'Censo de 1970. Hasta este evento estuvo registrada con clave (010010391).',
#  'Censo de 1980. Hasta este evento estuvo registrada con clave (010010360).',
#  'Censo de 1980. Hasta este evento estuvo registrada con clave (010010491).',
#  'Conteo de 1995. Pasa al municipio Jesús María (005) con clave (0393).',
#  'Censo de 2000. Localidad deshabitada',
#  'Censo de 2000. Localidad deshabitada ',
#  'Censo de 1990. Localidad con una vivienda. A partir de este evento cambia a la clave (010012259).',
#  'Censo de 2010. Se conurba a Villa Licenciado Jesús Terán (Calvillito) (0479).',
#  'Censo de 1910. Cambio de categoría política.',
#  'Conteo de 1995. Pasa al municipio El Llano (010) con clave (0147).',
#  'Conteo de 1995. Localidad de una vivienda. Cambio de nombre de localidad.',
#  'Censo de 2000.                    Se fusiona a Charco Prieto (El Palomar) (0093).',
#  'Conteo de 2005. Localidad conurbada a Villa Juárez (0059). ',
#  'Censo de 1930. Localidad deshabitada. Cambio de nombre de localidad.',
#  'Censo de 1990. Localidad deshabitada. Localidad con una vivienda.',
#  'Conteo de 1995. Localidad de una Vivienda.',
#  'Censo de 2010. Localidad conurbada a Calvillo 0001.',
#  'Censo de 1910. ',
#  'Censo de 1970. Cambio de nombre de localidad. Localidad deshabitada.',
#  'Censo de 1970. Localidad deshabitada. Localidad con dos viviendas.',
#  'Censo de 1990. Localidad con dos viviendas. Localidad deshabitada.',
#  'Censo de 1990. Se conurba a San Antonio de los Horcones 0084. ',
#  'Censo de 1990. Se conurba a Jesús María 0001.',
#  'Censo de 1990. Se fusiona a Los Sauces 0278.',
#  'Conteo de 1995. Pasa al municipio Pabellón de Arteaga 006 con clave 0260. ',
#  'Censo de 1990. A partir de este evento cambia a la clave 010050243.',
#  'Censo de 2000. Cambio de nombre de localidad. Baja de localidad.',
#  'Conteo de 1995. Localidad de una o dos viviendas. Cambio de nombre de localidad.',
#  'Censo de 2000. Se conurba a Jesús Gómez Portugal (Margaritas) 0041.',
#  'Censo de 2010. Localidad fusionada a Los Arquitos 0007.',
#  'Conteo de 2010. Localidad deshabitada ',
#  'Censo de 1960. Localidad deshabitada. Cambio de categoría política.',
#  'Censo de 1990. Se conurba a Pabellón de Arteaga 0001.',
#  'Censo de 1990. Se fusiona a Puerta del Milagro 0031.',
#  'Censo de 1990.  Localidad de dos viviendas. Cambio de nombre de localidad.',
#  'Censo de 1990. Se fusiona a Ojo Zarco 0024.',
#  'Conteo de 1995. Pasa al municipio Rincón de Romos 007 con clave 0357.',
#  'Censo de 1990. Localidad de una vivienda. A partir de este evento cambia a la clave 010060212.',
#  'Conteo de 1995. Pasa al municipio Rincón de Romos 007 con clave 0294.',
#  'Conteo de 1995. Se conurba a Pabellón de Arteaga 0001.',
#  'Censo de 1990. A partir de este evento cambia a la clave 010060235. Localidad de dos viviendas.',
#  'Conteo de 1995. Pasa al municipio Rincón de Romos 007 con clave 0312.',
#  'Conteo de 1995. Pasa al municipio Rincón de Romos 007 con clave 0383.',
#  'Conteo de 1995. Pasa al municipio Rincón de Romos 007 con clave 0354.',
#  'Conteo de 1995. Pasa al municipio Rincón de Romos 007 con clave 0408.',
#  'Censo de 2005. Localidad deshabitada  ',
#  'Censo de 2010. Localidad fusionada a Sector de Producción el Jagüey 0373.',
#  'Censo de 1990. A partir de este evento cambia a la clave 010070135. Localidad de una vivienda.',
#  'Censo de 2000. Localidad deshabitada  ',
#  'Censo de 2010. Localidad fusionada a Lázaro Cárdenas [Fraccionamiento] 0419.',
#  'Censo de 2000. Localidad deshabitada. ',
#  'Conteo de 2005. Localidad deshabitada.  ',
#  'Conteo de 2015. Localidad deshabitada.  ',
#  'Conteo de 2015. Localidad deshabitada ',
#  'Censo de 2020. Localidad deshabitada ',
#  'Conteo de 1995. Localidad deshabitada.  ',
#  'Censo de 2000. Baja de localidad. Cambio de nombre de localidad.',
#  'Censo de 2000. Baja de Localidad',
#  'Censo de 2000.    Se conurba a Tepezalá (0001).',
#  'Censo de 2010. Se conurba a San Antonio 0025.',
#  'Conteo de 1995. Pasa al municipio Asientos 002 con clave 0243.',
#  'Censo de 2000. Se conurba a Palo Alto (0001).',
#  'Conteo de 1995. Localidad deshabitada ',
#  'Conteo de 1995. Viene del municipio Pabellón de Arteaga (006) con clave (0142). Localidad deshabitada.  ',
#  'Conteo de 1995. Localidad deshabitada',
#  'Conteo de 1995. Localidad deshabitada.  .',
#  'Conteo de 1995. Viene del municipio Pabellón de Arteaga (006) con clave (0139).  Localidad de una vivienda.',
#  'Conteo de 1995. Viene del municipio Pabellón de Arteaga (006) con clave de localidad (0217). Localidad de una vivienda.',
#  'Conteo de 1995. Viene del municipio Pabellón de Arteaga (006) con clave (0072). Localidad de dos viviendas.',
#  'Conteo de 1995. Viene del municipio Pabellón de Arteaga (006) con clave (0242). Localidad de una vivienda.',
#  'Censo de 1970. Hasta este evento estuvo registrada con clave 010050044.',
#  'Conteo de 1995. Viene del municipio Pabellón de Arteaga (006) con clave (0060). Localidad de una vivienda.',
#  'Conteo de 1995. Localidad deshabitada  ',
#  'Conteo de 1995. Viene del municipio Pabellón de Arteaga (006) con clave (0244). Localidad de una vivienda.',
#  'Conteo de 1995. Viene del municipio Pabellón de Arteaga (006) con clave (0179). Localidad de dos viviendas.',
#  'Conteo de 1995. Localidad de dos viviendas. Viene del municipio Pabellón de Arteaga (006) con clave (0067).',
#  'Conteo de 1995. Viene del municipio Pabellón de Arteaga (006) con clave (0243). Localidad de una vivienda.',
#  'Conteo de 1995. Localidad deshabitada. ',
#  'Conteo de 1995. Viene del municipio Pabellón de Arteaga (006) con clave (0245). Localidad de una vivienda.',
#  'Censo de 2000. Localidad deshabitada.  ',
#  'Censo de 1990. Localidad de dos viviendas. Localidad deshabitada.',
#  'Censo de 1990. Localidad de una vivienda. Localidad deshabitada.',
#  'Censo de 1990. Localidad de una Vivienda.',
#  'Censo de 2010. Localidad conurbada a Asientos (010020001).',
#  'Conteo de 1995. Viene del municipio El Llano (010) con clave (0108).',
#  'Censo de 1970. Localidad dehabitada.',
#  'Censo de 1970. Hasta este evento estuvo registrada con clave (010010493).',
#  'Censo de 1995. Localidad deshabitada',
#  'Censo de 1980. Hasta este evento estuvo registrada con clave (010010724).',
#  'Censo de 1980. Hasta este evento estuvo registrada con clave (010010689).',
#  'Censo de 1980. Hasta este evento estuvo registrada con clave (010010733).',
#  'Censo de 1980. Hasta este evento estuvo registrada con clave (010010685).',
#  'Censo de 1970. Hasta este evento estuvo registrada con clave (010010343).',
#  'Censo de 1980. Hasta este evento estuvo registrada con clave (010010666).',
#  'Censo de 1970. Hasta este evento estuvo registrada con clave 010010311.',
#  'Censo de 1990. Viene del municipio Pabellón de Arteaga (006) con clave de localidad (0043).',
#  'Conteo de 1995. Localidad con una vivienda. Viene del municipio Asientos (002) con clave (0108).',
#  'Censo de 1990. Viene del municipio Aguascalientes (001) con clave (0654).',
#  'Conteo de 1995. Viene del municipio Jesús María (005) con clave (0215).',
#  'Censo de 1980. Hasta este evento estuvo registrada con clave 010070073.',
#  'Censo de 1980. Hasta este evento estuvo registrada con clave 010060062.',
#  'Censo de 1980. Hasta este evento estuvo registrada con clave 010060144.',
#  'Conteo de 1995. Localidad de una vivienda',
#  'Censo de 1980. Localidad de una vivienda.',
#  'Conteo de 1995. Viene del municipio Aguascalientes (001) con clave (1155).',
#  'Censo de 2010.         Localidad deshabitada.',
#  'Censo de 2010.               Localidad deshabitada.',
#  'Censo de 2010.                   Localidad deshabitada.',
#  'Censo de 2000.                                  ',
#  'Conteo de 1995.                               Localidad deshabitada.',
#  'Censo de 2010.            Localidad deshabitada.',
#  'Censo de 2010.                                   Localidad deshabitada.',
#  'Censo de 2000.                     ',
#  'Conteo de 1995. Localidad rehabilitada. Localidad deshabitada.',
#  'Censo de 2000. Localidad rehabilitada.           ',
#  'Conteo de 1995. Cambio de nombre de localidad. Localidad rehabilitada.',
#  'Censo de 2000.                           ',
#  'Censo de 2010.        Localidad deshabitada.',
#  'Conteo de 1995. Localidad rehabilitada. Cambio de nombre de localidad.  ',
#  'Conteo de 1995. Cambio de nombre de localidad.  ',
#  'Conteo de 1995. Baja de localidad. ',
#  'Censo de 2010.                    Localidad deshabitada.',
#  'Censo de 2010.   Localidad deshabitada.',
#  'Censo de 1980. Hasta este evento la localidad estuvo registrada con la clave. A partir de este evento la localidad cambia a la clave 02 003 0931. ',
#  'Conteo de 2005. Cambio de nombre de localidad. Cambio de nombre de localidad.',
#  'Censo de 1990.                                                      Cambio de nombre de localidad.',
#  'Censo de 1990.                                      ',
#  'Conteo de 1995.                           ',
#  'Conteo de 1995. Localidad rehabilitada.                   Localidad deshabitada.',
#  'Censo de 2010.                                 Localidad deshabitada.                                 ',
#  'Censo de 1990.                           ',
#  'Conteo de 1995. Cambio de nombre de localidad. ',
#  'Censo de 1990.                    Cambio de nombre de localidad.',
#  'Conteo de 1995. Localidad rehabilitada. Cambio de nombre de localidad. Localidad deshabitada.',
#  'Conteo de 1995.                 ',
#  'Conteo de 1995. Localidad rehabilitada.                    Localidad deshabitada.',
#  'Censo de 1990. ',
#  'Censo de 2000.                                     ',
#  'Censo de 1990.  Se conurba a Mexicali (0001).',
#  'Censo de 1990.Se conurba a Mexicali (0001).',
#  'Censo de 2010.       Localidad deshabitada.',
#  'Censo de 1990. Localidad rehabilitada.                                     Cambio de nombre de localidad.',
#  'Censo de 1980. Se conurba a Tijuana (0001).',
#  'Censo de 1990.  Cambio de nombre de localidad.',
#  'Censo de 2010.} Localidad deshabitada.',
#  'Conteo de 1995.                                 Localidad rehabilitada. Cambio de nombre de localidad. Localidad deshabitada.',
#  'Censo de 2010.                     Localidad deshabitada.',
#  'Censo de 1990.    Localidad rehabilitada.',
#  'Censo de 2000.                                                    ',
#  'Censo de 2010.                                  Localidad deshabitada.',
#  'Censo de 1990. Se conurba a Mexicali (0001).',
#  'Censo de 1990. Se conurba a Querétaro (0268).',
#  'Censo de 2010.              Localidad deshabitada.',
#  'Censo de 2000.                                    ',
#  'Conteo de 1995. Se conurba a Tijuana (0001).',
#  'Conteo de 1995. Localidad rehabilitada. Cambio de nombre de localidad.  Localidad deshabitada.',
#  'Censo de 1990. Se conurba a Guadalupe Victoria (Benito Juarez) (0185).',
#  'Censo de 1960. Localidad rehabilitada.  Localidad deshabitada.',
#  'Censo de 1990. Se conurba a Tijuana (0001).',
#  'Censo de 1990.                                                   Cambio de nombre de localidad.',
#  'Censo de 1950. Censó con la localidad Sierra de Juárez 020010251. Localidad deshabitada.',
#  'Censo de 1960. Localidad rehabilitada. Viene del municipio Tecate.',
#  'Censo de 2000.                              ',
#  'Conteo de 1995. Baja de localidad. Se conurba a  El Potrerito (0839).',
#  'Censo de 1995. Cambio de nombre de localidad.',
#  'Censo de 2010.     Localidad deshabitada.',
#  'Censo de 1950. Viene del municipio Tijuana. 004 0001.',
#  'Censo de 1970.  Baja de  localidad.',
#  'Censo de 1960. Localidad rehabilitada. Cambio de nombre de localidad. Localidad  deshabitada.',
#  'Conteo de 1995.                 . Cambio de nombre de localidad.',
#  'Censo de 1960.                                            Localidad deshabitada.',
#  'Conteo de 1995.                                                 ',
#  'Censo de 1960.                 Localidad deshabitada.',
#  'Censo de 1990. Cambio de nombre de localidad.            ',
#  'Censo de 2000. Localidad rehabilitada. Cambio de nombre de localidad.   ',
#  'Censo de 1980. Localidad rehabilitada. Localidad deshabitada.',
#  'Censo de 2000.                    ',
#  'Censo de 2010.      Localidad deshabitada.',
#  'Censo de 1990.   Cambio de nombre de localidad',
#  'Censo de 2000.                            ',
#  'Censo de 2010.                             Localidad deshabitada.',
#  'Censo de 1980. Cambio de nombre de localidad. Localidad deshabitada.',
#  'Censo de 1990.  Baja de localidad.',
#  'Censo de 1950. Viene del municipio Tijuana (004) con clave de localidad (0696).',
#  'Censo de 1960. Localidad rehabilitada. Cambio de nombre de localidad. Localidad deshabitada.',
#  'Censo de 1970.                   Cambio de nombre de localidad.',
#  'Censo de 1950. Censó con la localidad Guadalupe 020010114. Localidad deshabitada.',
#  'Censo de 1990. Se conurba a Delta (Estacion Delta) (0159).',
#  'Censo de 2000.                                             ',
#  'Censo de 1950. Localidad rehabilitada. Cambio de nombre de localidad.',
#  'Censo de 1990. Se conurba a Puebla (0262).',
#  'Censo de 1960. Localidad rehabilitada. Viene del municipio Tijuana.',
#  'Censo de 1990.  Localidad rehabilitada. Cambio de nombre de localidad.',
#  'Censo de 2000.   Cambio de nombre de localidad.',
#  'Censo de 1950. Censó con la localidad Santo Tomás 020010242. Localidad deshabitada.',
#  'Censo de 1960. Localidad rehabilitada. ',
#  'Conteo de 1995. Se conurba a Mexicali (0001).',
#  'Censo de 1960. Viene del municipio Tecate 003.',
#  'Censo de 1950. Viene del municipio Tijuana (004) con clave de localidad  (0730).',
#  'Conteo de 1995. Localidad rehabilitada. Cambio de nombre de localidad. ',
#  'Conteo de 1995.            Localidad rehabilitada.      ',
#  'Censo de 2000.                                      ',
#  'Censo de 1990. Se conurba a Benito Juárez (Tecolotes) (0456).',
#  'Censo de 1990. Se conurba a  Paredones (0456).',
#  'Censo de 1990. Se conurba a Benito Juárez Tecolotes (0456).',
#  'Censo de 1990. Se conurba a Paredones (0459).',
#  'Censo de 1990. Se conurba a  Guadalupe Victoria (0185).',
#  'Censo de 1950. Censó con la localidad la Calentura 020010059.',
#  'Censo de 2010.    Localidad deshabitada.',
#  'Censo de 1980. Cambio de nombre de localidad. Localidad rehabilitada.                   Localidad deshabitada.',
#  'Censo de 2010.                                                     Localidad deshabitada.',
#  'Conteo de 1995. Localidad deshabitada. Cambio de nombre de localidad.',
#  'Censo de 1950. Viene del municipio Tijuana clave 02004. Localidad deshabitada.',
#  'Censo de 2000.                                         ',
#  'Censo de 1990. Baja de localidad.                                                             Cambio de nombre de localidad.',
#  'Censo de 2000. Localidad rehabilitada. Cambio de nombre de localidad. ',
#  'Censo de 2000.                        ',
#  'Conteo de 1995.. Cambio de nombre de localidad. ',
#  'Censo de 2000. Localidad rehabilitada. Cambio de nombre de localidad.  ',
#  'Censo de 2000. Cambio de nombre de localidad.  ',
#  'Censo de 1990.                         Cambio de nombre de localidad.                                         ',
#  'Conteo de 1995. Cambio de nombre de localidad.   ',
#  'Censo de 1940. Viene del municipio Tecate (003) con clave de localidad (0029).',
#  'Censo de 2000.                                           ',
#  'Censo de 1990. Baja de localidad. ',
#  'Censo de 2000. Cambio de nombre de localidad. ',
#  'Censo de 2010. Cambio de nombre de localidad.   Localidad rehabilitada.',
#  'Censo de 2000.                                   ',
#  'Censo de 1950. Censo en la Ciudad de Ensenada. Localidad deshabitada.',
#  'Censo de 1950. Censó con la localidad Real del Castillo 020010190.                            Localidad deshabitada.',
#  'Censo de 2010.                                     Localidad deshabitada.',
#  'Censo de 2010.                                               Localidad deshabitada.',
#  'Censo de 1950. Localidad rehabilitada. Cambio de nombre de localidad. Censó con la localidad Sierra de Juárez 020010251. Localidad deshabitada.',
#  'Censo de 2010. Cambio de nombre de localidad',
#  'Censo de 2010.                                          Localidad deshabitada.',
#  'Censo de 2010.                                           Localidad deshabitada.',
#  'Conteo de 1995. Cambio de nombre de localidad. Localidad deshabitada. ',
#  'Censo de 2010.                                              Localidad deshabitada.',
#  'Censo de 2010.                                         Localidad deshabitada.',
#  'Censo de 2010.                                                  Localidad deshabitada.',
#  'Conteo de 1995.            Localidad deshabitada.',
#  'Censo de 2010.                                                 ',
#  'Censo de 1960. Localidad rehabilitada. Cambio de categoría política.',
#  'Censo de 2010.                                                Localidad deshabitada.',
#  'Censo de 1930. Cambio de nombre de localidad. Viene del municipio Ensenada.',
#  'Censo de 2010.                                                 Localidad deshabitada.',
#  'Censo de 2010.                   Cambio de nombre de localidad.',
#  'Censo de 2010.                                            Localidad deshabitada.',
#  'Censo de 2010.                   Cambio de nombre de localidad.  ',
#  'Censo de 2010.                                             Localidad deshabitada.',
#  'Censo de 2010.                                        Localidad deshabitada.',
#  'Censo de 1950. Censó con la localidad Ensenada 020010001.',
#  'Censo de 2010.                                      Localidad deshabitada.',
#  'Censo de 2010.                        Cambio de nombre de localidad. ',
#  'Censo de 2010.                                    Localidad deshabitada.',
#  'Censo de 2010.  Cambio de nombre de localidad.',
#  'Censo de 2010.             Localidad deshabitada.',
#  'Censo de 2010.                Localidad deshabitada.',
#  'Censo de 2010.        Cambio de nombre de localidad.',
#  'Censo de 2010.          Localidad deshabitada.',
#  'Censo de 1950. Localidad rehabilitada. Cambio de categoría política.',
#  'Censo de 1950. Viene del municipio Tijuana (004) con clave de localidad (0673). Localidad deshabitada.',
#  'Censo de 1939. Cambio de nombre de localidad.',
#  'Conteo de 1995.            Cambio de nombre de localidad',
#  'Conteo de 2005.  Cambio de nombre de localidad.',
#  'Censo de 1960. ',
#  'Censo de 1990. Se conurba a Ensenada (0001).',
#  'Censo de 1980. Localidad rehabilitada.              Cambio de nombre de localidad.',
#  'Censo de 2010.                  Localidad deshabitada.',
#  'Conteo de 2005.                                              ',
#  'Censo de 1930. Viene del municipio Ensenada 001.',
#  'Censo de 1930. Viene del municipio Tecate clave 02003.',
#  'Censo de 1930. Localidad rehabilitada. Cambio de nombre de localidad. Viene del municipio Tecate (003) con clave de localidad (0730).  Cambio de categoría política.',
#  'Censo de 1990.                                                     ',
#  'Censo de 1950. Localidad rehabilitada. Cambio de nombre del municipio.',
#  'Conteo de 2005.                                                 ',
#  'Censo de 1990. Se conurba a Rosarito (0223).',
#  'Censo de 2010.    Cambio de nombre de localidad.',
#  'Conteo de 2005.                                             ',
#  'Censo de 2010. Baja de localidad. ',
#  'Censo de 2010. ',
#  'Conteo de 2005.                                                ',
#  'Censo de 2010.   Cambio de nombre de localidad.',
#  'Censo de 1980.              Cambio de nombre de localidad.',
#  'Conteo de 2005.                                                  ',
#  'Censo de 2010.                        Localidad deshabitada.',
#  'Censo de 2010.       Cambio de nombre de localidad.',
#  'Conteo de 2005.                                           ',
#  'Censo de 2010.      Cambio de nombre de localidad.',
#  'Conteo de 2005.                                            ',
#  'Censo de 1940. Viene del municipio Tijuana (004) con clave de localidad  (0713).',
#  'Censo de 1990. Cambio de nombre de localidad. ',
#  'Conteo de 2005.                                     ',
#  'Conteo de 2005.                                          ',
#  'Censo de 1930. Viene del municipio Ensenada.',
#  'Censo de 1970. Viene del municipio Tecate.  ',
#  'Censo de 1930. Cambio de nombre de localidad. Viene del municipío Tecate (003) con clave de localidad (0696).',
#  'Censo de 1970. Localidad rehabilitada.         ',
#  'Censo de 1950. Viene del municipio Tecate.',
#  'Censo de 1950. Censó con la localidad San Vicente 020010243.',
#  'Censo de 1960.                   Localidad deshabitada.',
#  'Censo de 2000.                                                   ',
#  'Conteo de 2005.                                               ',
#  'Censo de 1990.                                          ',
#  'Censo de 1930. Cambio de categoría política.',
#  'Conteo de 2005.                                         ',
#  'Censo de 1960. Cambio de nombre de localidad. Localidad rehabilitada. Viene del municipio Tijuana (004) con clave de localidad (0318).  Localidad deshabitada.',
#  'Conteo de 2005. Cambio de nombre de localidad.                                      ',
#  'Censo de 1930. Localidad rehabilitada. Cambio de nombre de localidad. Viene del municipio Tecate clave 02003.',
#  'Censo de 1930. Localidad rehabilitada. Cambio de nombre del municipio.',
#  'Conteo de 2005.                                      ',
#  'Conteo de 2005. Localidad rehabilitada. ',
#  'Censo de 1930. Localidad rehabilitada. Cambio de nombre del municipio. Cambio de categoría política.',
#  'Conteo de 1995. Se conurba a Guadalupe Victoria (Kilometro 43) ( 0185).',
#  'Conteo de 2005. Localidad rehabilitada.                    ',
#  'Censo de 1990. Cambio de nombre de localidad. A partir de este evento la localidad cambia a la clave 003 0334.',
#  'Conteo de 2005. Cambio de nombre de localidad. ',
#  'Conteo de 2005.                                        ',
#  'Censo de 1940. Documento. S/n. Viene del municipio Tijuana. Localidad deshabitada.',
#  'Censo de 2000.                                                     ',
#  'Censo de 2000. Baja de localidad.   Cambio de nombre de localidad.',
#  'Censo de 2000. Localidad deshabitada.  Cambio de nombre de localidad.',
#  'Censo de 1930. Cambio de nombre de localidad. Viene del municipio Tecate (003) con clave de localidad  (0215).',
#  'Conteo de 2005. Cambio de nombre de localidad.    ',
#  'Conteo de 2005. Localidad rehabilitada. Cambio de nombre de localidad',
#  'Censo de 2010. Cambio de nombre de localidad. ',
#  'Censo de 1939. Localidad rehabilitada. Cambio de nombre del municipio.',
#  'Censo de 2010. Cambio de nombre de localidad. Localidad rehabilitada.',
#  'Censo de 1930. Viene del municipio Tecate. 003 0001.',
#  'Censo de 1970. A partir de este evento la localidad cambia a la clave 003 0106.',
#  'Censo de 1950. Censó con la localidad Santa Catarina 020010232.',
#  'Censo de 2010. Localidad deshabitada.          Localidad rehabilitada ',
#  'Conteo de 1995. Cambio de nombre de localidad. A partir de este evento cambia a la clave 020021400.',
#  'Censo de 1990.                                        ',
#  'Censo de 1990. Se conurba a Mexicali 0001.',
#  'Conteo de 1995.                                     ',
#  'Censo de 1930. Cambio de categoría política. Cambio de nombre de localidad.',
#  'Censo de 2010.                                Cambio de nombre de localidad.          ',
#  'Conteo de 2005.                                ',
#  'Censo de 2010.   ',
#  'Conteo de 2005.                                       ',
#  'Censo de 2000.                                               ',
#  'Censo de 1939. Localidad rehabilitada. Cambio de nombre de localidad. Cambio de nombre de la sección municipal.',
#  'Censo de 1960. Localidad deshabitada. Cambio de nombre de localidad. Cambio de categoría política.',
#  'Censo de 2000.                                        ',
#  'Censo de 1930. Localidad rehabilitada. Cambio de nombre de localidad.',
#  'Censo de 1940. Localidad rehabilitada. Cambio de nombre de localidad. Viene de la sección municipal de San Telmo.',
#  'Censo de 2010.                                      Cambio de nombre de localidad.',
#  'Censo de 1939. Localidad rehabilitada.',
#  'Censo de 1930. Localidad Rahabilitada.',
#  'Conteo de 1995. Localidad rehabilitada.                                Cambio de nombre de localidad.      ',
#  'Censo de 1960. Localidad rehabilitada. Viene del municipio Tijuana (004) con clave de localidad (0044).  Localidad deshabitada.',
#  'Censo de 2000. Localidad deshabitada. Localidad deshabitada. ',
#  'Censo de 2000.                                            ',
#  'Censo de 1990.                               Cambio de nombre de localidad.                                      ',
#  'Conteo de 1995.                                  ',
#  'Censo de 1921. Cambio de nombre del municipio.',
#  'Censo de 2000.                               Localidad deshabitada.                               Cambio de nombre de localidad.',
#  'Censo de 1950. Localidad rehabilitada. Cambio de nombre de la sección municipal. Localidad deshabitada.',
#  'Conteo de 2005. Cambio de nombre de localidad. Localidad rehabilitada.',
#  'Censo de 1921. Viene de la sección municipal de San Telmo. Cambio de categoría política.',
#  'Censo de 2000.                                          ',
#  'Censo de 1960. Localidad rehabilitada. Cambio de nombre de localidad. Cambio de categoría política. Localidad deshabitada.',
#  'Censo de 2000. Se conurba a Lázaro Cárdenas (Valle de la Trinidad) (0935).',
#  'Censo de 1921. Cambio de nombre del municipio. Cambio de categoría política.',
#  'Censo de 1930. Cambio de nombre del municipio.',
#  'Censo de 2000.                                       ',
#  'Censo de 1950. Viene del municipio Tijuana con clave 004. Localidad deshabitada.',
#  'Censo de 1921. Cambio de nombre de la sección municipal.',
#  'Censo de 1921. Viene de la sección municipal de Calnali.',
#  'Censo de 1980. Localidad rehabilitada. Hasta este evento la localidad estuvo registrada con la clave 003 0239.',
#  'Censo de 1921. Cambio de nombre de localidad. Cambio de nombre de la sección municipal. Cambio de categoría política.',
#  'Conteo de 2005. Cambio de nombre de localidad. Localidad deshabitada.',
#  'Censo de 1930. Cambio de nombre de la sección municipal. Cambio de categoría política.',
#  'Censo de 1921. Cambio de nombre de la sección municipal. Cambio de categoría política.',
#  'Censo de 2000.                                                 ',
#  'Conteo de 1995. Localidad Rehabilitada. Localidad deshabitada.  ',
#  'Censo de 1995. Baja de localidad.',
#  'Censo de 1990. Se conurba a Santa Isabel (0289).',
#  'Censo de 1921. Cambio de nombre de localidad. Viene de la sección municipal de Calnali. Cambio de categoría política.',
#  'Censo de 1921. Viene del municipio Tijuana 004.',
#  'Censo de 2000. ',
#  'Censo de 2000.                                              ',
#  'Censo de 2000.                                                ',
#  'Conteo de 2005.             Cambio de nombre de localidad.',
#  'Conteo de 1995. Localidad rehabilitada.       ',
#  'Conteo de 1995. Localidad rehabilitada. Cambio de nombre de localidad. A partir de este evento cambia a la clave 020021413.',
#  'Censo de 1980. Localidad rehabilitada. Cambio de nombre de la sección municipal.',
#  'Censo de 1950. Localidad rehabilitada. Cambio de nombre de localidad. Cambio de categoría política.',
#  'Conteo de 1995. Localidad rehabilitada.        Localidad deshabitada.',
#  'Conteo de 2005.  Localidad deshabitada.',
#  'Censo de 1980. ',
#  'Censo de 1990.        ',
#  'Censo de 1921. Cambio de nombre de localidad. Cambio de nombre del municipio.',
#  'Conteo de 2005.                          Cambio de nombre de localidad. Localidad deshabitada.',
#  'Censo de 2000. Baja de localidad. ',
#  'Censo de 1940. Localidad rehabilitada.        ',
#  'Censo de 1990. Se conurba a la Joya (0187).',
#  'Censo de 1950. Censó con la localidad El Marmol 020010142.',
#  'Censo de 1930. Localidad rehabilitada. Cambio de nombre del municipio. Localidad deshabitada.',
#  'Censo de 1939. Localidad rehabilitada. Cambio de nombre de sección municipal.',
#  'Conteo de 1995. Cambio de nombre de localidad.  Localidad deshabitada.',
#  'Censo de 1990.  ',
#  'Censo de 1950. Censó con la localidad El Sauzal 020010247.',
#  'Censo de 2000. Pasa al municipio Tecate (003) con clave de localidad (0606).',
#  'Censo de 2000. Pasa al municipio Tecate (003) con clave de localidad (0173).',
#  'Censo de 1921. Viene del municipio Tecate (003) con clave de localidad (0083).',
#  'Censo de 1921. Viene del municipio Tijuana.',
#  'Censo de 1950. Viene del municipio Tijuana (004)con clave de localidad  (0732).',
#  'Censo de 1960. Localidad rehabilitada. Cambio de nombre de localidad. Cambio de categoría política.',
#  'Censo de 1990. Se conurba a Primo Tapia (0216). ',
#  'Censo de 1950. Baja de localidad a.',
#  'Censo de 1990.                                     ',
#  'Conteo de 1995.   Cambio de nombre de localidad.',
#  'Conteo de 2005.   Cambio de nombre de localidad. Localidad rehabilitada.',
#  'Censo de 1970. Localidad rehabilitada. Viene de la sección municipal San Quintin.',
#  'Conteo de 2005.  Cambio de nombre de localidad. Localidad deshabitada.',
#  'Censo de 2000. Localidad deshabitada.          Cambio de nombre de localidad.',
#  'Conteo de 1995.Se conurba a Playas de Rosarito (0001).',
#  'Censo de 1950. Viene del municipio Tijuana (003) con clave de localidad (0669). Localidad deshabitada.',
#  'Censo de 1930. Cambio de nombre de localidad. Viene del municipio Tecate clave 02003.',
#  'Conteo de 2005.      Cambio de nombre de localidad.',
# ...
#  'Conteo de 1995. Localidad deshabitada.                    ',
#  'Censo de 1950. Censó con la localidad San Vicente 020010243.  Localidad deshabitada.',
#  'Conteo de 2005. Ley Orgánica de la Administración Pública Municipal del Estado de B. C. del 30 de septiembre de 1989. Aplicado en 2005. Viene del municipio Tijuana (004) con clave de localidad (0403).',
#  'Conteo de 2005. Ley Orgánica de la Administración Pública Municipal del Estado de B. C. del 30 de septiembre de 1989. Aplicado en 2005. Viene del municipio Tijuana (004) con clave de localidad (0532).',
#  'Conteo de 2005. Ley Orgánica de la Administración Pública Municipal del Estado de B. C. del 30 de septiembre de 1989. Aplicado en 2005. Viene del municipio Tijuana (004) con clave de localidad (1327).',
#  'Conteo de 2005. Ley Orgánica de la Administración Pública Municipal del Estado de B. C. del 30 de septiembre de 1989. Aplicado en 2005. Viene del municipio Tijuana (004) con clave de localidad (1478).',
#  'Conteo de 2005. Ley Orgánica de la Administración Pública Municipal del Estado de B. C. del 30 de septiembre de 1989. Aplicado en 2005. Viene del municipio Tijuana (004) con clave de localidad (1496).',
#  'Censo de 1900. Pasa al municipio Tijuana.',
#  'Censo de 1900. Pasa al municipio Tijuana 004.',
#  'Censo de 1921. Pasa al municipio Tijuana 004.',
#  'Censo de 1980.      Localidad deshabitada.',
#  'Censo de 1980.                  Localidad deshabitada.',
#  'Censo de 1980.                      Localidad deshabitada.',
#  'Censo de 1910. Pasa a la sección municipal de Ensenada.',
#  'Censo de 1900. Pasa a la sección municipal de San Telmo.',
#  'Censo de 1980.                                    Localidad deshabitada.',
#  'Censo de 1990.                         Localidad deshabitada.',
#  'Censo de 1990.                  Localidad deshabitada.',
#  'Censo de 1990. Pasa al municipio  Playas de Rosarito (005) con clave de localidad (0139). Localidad deshabitada.',
#  'Censo de 1990.              Localidad deshabitada.',
#  'Censo de 1990.                      Localidad deshabitada.',
#  'Censo de 1990.                       Localidad deshabitada.',
#  'Censo de 1990.                        Localidad deshabitada.',
#  'Censo de 1900. Pasa a la sección municipal de Calnali.',
#  'Censo de 2000.                       ',
#  'Censo de 1990.                    Localidad deshabitada.',
#  'Censo de 1990.                                    Localidad deshabitada.',
#  'Censo de 1990.                                   Localidad deshabitada.',
#  'Censo de 1990.                   Localidad deshabitada.',
#  'Censo de 1900. Pasa a la sección municipal de El Alamo.',
#  'Conteo de 1995. Se conurba a Tijuana (0001). Localidad deshabitada.',
#  'Conteo de 1995. Se conurba a Tijuana (0001).        Localidad deshabitada.',
#  'Conteo de 1995. Se conurba a Tijuana (0001).         Localidad deshabitada.',
#  'Conteo de 1995.                   Localidad deshabitada.',
#  'Conteo de 1995.           Localidad deshabitada.',
#  'Conteo de 1995.    Localidad deshabitada.',
#  'Conteo de 1995.                  Localidad deshabitada.',
#  'Censo de 1980. Hasta este evento estuvo registrada con clave 020020398.',
#  'Conteo de 2005. Localidad deshabitada. Ley Orgánica de la Administración Pública Municipal del Estado de B.C. del 30 septiembre de 1989. Aplicado en 2005. Viene del municipio Ensenada (001) con clave de localidad (0822). Localidad deshabitada.',
#  'Conteo de 2005. Localidad deshabitada. Ley Orgánica de la Administración Publica Municipal del Estado de B.C. del 30 de septiembre de 1989. Aplicado en 2005. Viene del municipio Ensenada (001) con clave de localidad (1254). Localidad deshabitada.',
#  'Conteo de 2005. Localidad deshabitada. Ley Orgánica de la Administración Pública Municipal del Estado de B.C. del 30 de septiembre de 1989. Aplicado en 2005. Viene del municipio Ensenada (001) con clave de localidad (1553). Localidad deshabitada.',
#  'Conteo de 2005. Localidad deshabitada. Ley Orgánica de la Administración Pública Municipal del Estado de B.C. del 30 de septiembre de 1989. Aplicado en 2005. Viene del municipio  Ensenada (001) con clave de localidad (1554).',
#  'Conteo de 2005. Ley Orgánica de la Administración Pública Municipal del Estado de B.C. del 30 de septiembre de 1989. Aplicado en 2005. Viene del municipio Ensenada (001) con clave de localidad (3101).',
#  'Conteo de 2005. Localidad deshabitada. Ley Orgánica de la Administración Pública Municipal del Estado de B.C. del 30 de septiembre de 1989. Aplicado en 2005. Viene del municipio Ensenada (001) con clave de localidad (3386).',
#  'Conteo de 2005. Ley Orgánica de la Administración Pública Municipal del Estado de B.C. del 30 de septiembre de 1989. Aplicado en 2005. Viene del municipio Ensenada (001) con clave de localidad (3402).',
#  'Conteo de 2005. Ley Orgánica de la Administración Pública Municipal del Estado de B.C. del 30 de septiembre de 1989. Aplicado en 2005. Viene del municipio Ensenada (001) con clave de localidad (4117).',
#  'Conteo de 2005. Localidad deshabitada. Ley Orgánica de la Administración Pública Municipal del Estado de B.C. del 30 de septiembre de 1989. Aplicado en 2005. Viene del municipio Ensenada (001) con clave de localidad (4118).',
#  'Conteo de 2005. Localidad deshabitada. Ley Orgánica de la Administración Pública Municipal del Estado de B.C. del 30 de septiembre de 1989. Aplicado en 2005. Viene del municipio Ensenada (001) con clave de localidad (4132).',
#  'Conteo de 2005. Ley Orgánica de la Administración Pública Municipal del Estado de B.C. del 30 de septiembre de 1989. Aplicado en 2005. Viene del municipio Tecate (003) con clave de localidad (0605).',
#  'Conteo de 2005. Ley Orgánica de la Administración Pública Municipal del Estado de B.C. del 30 de septiembre de 1989. Aplicado en 2005. Viene del municipio Tecate (003) con clave de localidad (0824).',
#  'Conteo de 2005. Localidad deshabitada. Ley Orgánica de la Administración Pública Municipal del Estado de B.C. del 30 de septiembre de 1989. Aplicado en 2005. Viene del municipio Ensenada (001) con Clave de Localidad (1161).',
#  'Censo de 1950. Censó con la localidad San Vicente 020010243. Localidad deshabitada.',
#  'Conteo de 1995.                                                 Localidad deshabitada.',
#  'Conteo de 1995.                                                         Localidad deshabitada.',
#  'Censo de 1990.        Localidad deshabitada.',
#  'Conteo de 2005. Ley Orgánica de la Administración Pública Municipal del Estado de B. C. del 30 de septiembre de 1989. Aplicado en 2005. Viene del municipio Tecate (003) con clave de localidad (0005).',
#  'Conteo de 2005. Ley Orgánica de la Administración Pública Municipal del Estado de B. C. del 30 de septiembre de 1989. Aplicado en 2005. Viene del municipio Tecate (003) con clave de localidad (0026). Cambio de nombre de localidad.',
#  'Conteo de 2005. Ley Orgánica de la Administración Pública Municipal del Estado de B. C. del 30 de septiembre de 1989. Aplicado en 2005. Viene del municipio Tecate (003) con clave de localidad (0047).',
#  'Conteo de 2005. Ley Orgánica de la Administración Pública Municipal del Estado de B. C. del 30 de septiembre de 1989. Aplicado en 2005. Viene del municipio Tecate (003) con clave de localidad (0082).',
#  'Conteo de 2005. Ley Orgánica de la Administración Pública Municipal del Estado de B. C. del 30 de septiembre de 1989. Aplicado en 2005. Viene del municipio Tecate (003) con clave de localidad (0125). Cambio de nombre de localidad.',
#  'Conteo de 2005. Ley Orgánica de la Administración Pública Municipal del Estado de B. C. del 30 de septiembre de 1989. Aplicado en 2005. Viene del municipio Tecate (003) con clave de localidad (0140).',
#  'Conteo de 2005. Ley Orgánica de la Administración Pública Municipal del Estado de B. C. del 30 de septiembre de 1989. Aplicado en 2005. Viene del municipio Tecate (003) con clave de localidad (0259).',
#  'Conteo de 2005. Ley Orgánica de la Administración Pública Municipal del Estado de B. C. del 30 de septiembre de 1989. Aplicado en 2005. Viene del municipio Tecate (003) con clave de localidad (0720).',
#  'Conteo de 2005. Ley Orgánica de la Administración Pública Municipal del Estado de B. C. del 30 de septiembre de 1989. Aplicado en 2005. Viene del municipio Tecate (003) con clave de localidad (0721).',
#  'Conteo de 2005. Ley Orgánica de la Administración Pública Municipal del Estado de B. C. del 30 de septiembre de 1989. Aplicado en 2005. Viene del municipio Tecate (003) con clave de localidad (0724).',
#  'Conteo de 2005. Ley Orgánica de la Administración Pública Municipal del Estado de B. C. del 30 de septiembre de 1989. Aplicado en 2005. Viene del municipio Tecate (003) con clave de localidad (0728).',
#  'Conteo de 2005. Ley Orgánica de la Administración Pública Municipal del Estado de B. C. del 30 de septiembre de 1989. Aplicado al 2005. Viene del municipio Tecate (003) con clave de localidad (0736).',
#  'Conteo de 2005. Ley Orgánica de la Administración Pública Municipal del Estado de B. C. del 30 de septiembre de 1989. Aplicado en 2005. Viene del municipio Tecate (003) con clave de localidad (0738).',
#  'Conteo de 2005. Ley Orgánica de la Administración Pública Municipal del Estado de B. C. del 30 de septiembre de 1989. Aplicado en 2005. Viene del municipio Tecate (003) con clave de localidad (0740).',
#  'Conteo de 2005. Ley Orgánica de la Administración Pública Municipal del Estado de B. C. del 30 de septiembre de 1989. Aplicado en 2005. Viene del municipio Tecate (003) con clave de localidad (0745).',
#  'Conteo de 2005. Ley Orgánica de la Administración Pública Municipal del Estado de B. C. del 30 de septiembre de 1989. Aplicado en 2005. Viene del municipio Tecate (003) con clave de localidad (0748).',
#  'Conteo de 2005. Ley Orgánica de la Administración Pública Municipal del Estado de B. C. del 30 de septiembre de 1989. Aplicado en 2005. Viene del municipio Tecate (003) con clave de localidad (0750).',
#  'Conteo de 2005. Ley Orgánica de la Administración Pública Municipal del Estado de B. C. del 30 de septiembre de 1989. Aplicado en 2005. Viene del municipio Tecate (003) con clave de localidad (0782).',
#  'Conteo de 2005. Ley Orgánica de la Administración Pública Municipal del Estado de B. C. del 30 de septiembre de 1989. Aplicado en 2005. Viene del municipio Tecate (003) con clave de localidad (0801).',
#  'Conteo de 2005. Ley Orgánica de la Administración Pública Municipal del Estado de B. C. del  30 de septiembre de 1989. Aplicado en 2005. Viene del municipio Tecate (003) con clave de localidad (0804). Cambio de nombre de localidad.',
#  'Conteo de 2005. Ley Orgánica de la Administración Pública Municipal del Estado de B. C. del 30 de septiembre de 1989. Aplicado en 2005. Viene del municipio Tecate (003) con clave de localidad (0819).',
#  'Conteo de 2005. Ley Orgánica de la Administración Pública Municipal del Estado de B. C. del 30 de septiembre de 1989. Aplicado en 2005. Viene del municipio Tecate (003) con clave de localidad (0958).',
#  'Conteo de 2005. Ley Orgánica de la Administración Pública Municipal del Estado de B. C. del 30 de septiembre de 1989. Aplicado en 2005. Viene del municipio Tecate (003) con clave de localidad (0961).',
#  'Conteo de 2005. Ley Orgánica de la Administración Pública Municipal del Estado de B. C. del 30 de septiembre de 1989. Aplicado en 2005. Viene del municipio Tecate (003) con clave de localidad (0966).',
#  'Conteo de 2005. Ley Orgánica de la Administración Pública Municipal del Estado de B. C. del 30 de septiembre de 1989. Aplicado en 2005. Viene del municipio Tecate (003) con clave de localidad (0970).',
#  'Conteo de 2005. Ley Orgánica de la Administración Pública Municipal del Estado de B. C. del 30 de septiembre de 1989. Aplicado en 2005. Viene del municipio Tecate (003) con clave de localidad (0973).',
#  'Conteo de 2005. Ley Orgánica de la Administración Pública Municipal del Estado de B. C. del 30 de septiembre de 1989. Aplicado en 2005. Viene del municipio Tecate (003) con clave de localidad (0974).',
#  'Conteo de 2005. Ley Orgánica de la Administración Pública Municipal del Estado de B. C. del 30 de septiembre de 1989. Aplicado en 2005. Viene del municipio Tecate (003) con clave de localidad (0988).',
#  'Conteo de 2005. Ley Orgánica de la Administración Pública Municipal del Estado de B. C. del 30 de septiembre de 1989. Aplicado en 2005. Viene del municipio Tecate (003) con clave de localidad (1002).',
#  'Conteo de 2005. Ley Orgánica de la Administración Pública Municipal del Estado de B. C. del 30 de septiembre de 1989. Aplicado en 2005. Viene del municipio Tecate (003) con clave de localidad (1003). Cambio de nombre de localidad.',
#  'Conteo de 2005. Ley Orgánica de la Administración Pública Municipal del Estado de B. C. del 30 de septiembre de 1989. Aplicado en 2005. Viene del municipio Tecate (003) con clave de localidad (1004).',
#  'Conteo de 1995.        ',
#  'Conteo de 2005. Ley Orgánica de la Administración Pública Municipal del Estado de B. C. del 30 de septiembre de 1989. Aplicado en 2005. Viene del municipio Tecate (003) con clave de localidad (1008). Cambio de nombre de localidad.',
#  'Conteo de 1995.           ',
#  'Conteo de 2005. Ley Orgánica de la Administración Pública Municipal del Estado de B. C. del 30 de septiembre de 1989. Aplicado en 2005. Viene del municipio Tecate (003) con clave de localidad (1429).',
#  'Conteo de 2005. Ley Orgánica de la Administración Pública Municipal del Estado de B. C. del 30 de septiembre de 1989. Aplicado en 2005. Viene del municipio Tecate (003) con clave de localidad (1441).',
#  'Conteo de 2005. Ley Orgánica de la Administración Pública Municipal del Estado de B. C. del 30 de septiembre de 1989. Aplicado en 2005. Viene del municipio Tecate (003) con clave de localidad (1448).',
#  'Conteo de 2005. Ley Orgánica de la Administración Pública Municipal del Estado de B. C. del 30 de septiembre de 1989. Aplicado en 2005. Viene del municipio Tecate (003) con clave de localidad (1503).',
#  'Conteo de 2005. Ley Orgánica de la Administración Pública Municipal del Estado de B. C. del 30 de septiembre de 1989. Aplicado en 2005. Viene del municipio Tecate (003) con clave de localidad (1514).',
#  'Conteo de 2005. Ley Orgánica de la Administración Pública Municipal del Estado de B. C. del 30 de septiembre de 1989. Aplicado en 2005. Viene del municipio Tecate (003) con clave de localidad (1542).',
#  'Conteo de 2005. Ley Orgánica de la Administración Pública Municipal del Estado de B. C. del 30 de septiembre de 1989. Aplicado en 2005. Viene del municipio  Tecate (003) con clave de localidad (1543).',
#  'Conteo de 2005. Ley Orgánica de la Administración Pública Municipal del Estado de B. C. del 30 de septiembre de 1989. Aplicado en 2005. Viene del municipio Tecate (003) con clave de localidad (1544).',
#  'Conteo de 2005. Ley Orgánica de la Administración Pública Municipal del Estado de B. C. del 30 de septiembre de 1989. Aplicado en 2005. Viene del municipio Tecate (003) con clave de localidad (1545).',
#  'Conteo de 2005. Ley Orgánica de la Administración Pública Municipal del Estado de B. C. del 30 de septiembre de 1989. Aplicado en 2005. Viene del municipio Tecate (003) con clave de localidad (1588).',
#  'Conteo de 2005. Ley Orgánica de la Administración Pública Municipal del Estado de B. C. del 30 de septiembre de 1989. Aplicado en 2005. Viene del municipio Tecate (003) con clave de localidad (1594).',
#  'Conteo de 2005. Ley Orgánica de la Administración Pública Municipal del Estado de B. C. del 30 de septiembre de 1989. Aplicado en 2005. Viene del municipio Tecate (003) con clave de localidad (0264).',
#  'Conteo de 2005. Ley Orgánica de la Administración Pública Municipal del Estado de B. C. del 30 de septiembre de 1989. Aplicado en 2005. Viene del municipio Tecate (003) con clave de localidad (0949).',
#  ...]

# %%
list(censal_mas_info.str.replace(r'^(Censo de |Conteo de )\d{4}\.', '').unique()[20:])
# Out:
# C:\Users\Lorrain\AppData\Local\Temp\ipykernel_5516\3409716397.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   list(censal_mas_info.str.replace(r'^(Censo de |Conteo de )\d{4}\.', '').unique()[20:])
# ['\r\nCambio de nombre de localidad.\r\nLocalidad con una vivienda.',
#  '\r\nLocalidad rehabilitada.\r\nLocalidad con una vivienda.',
#  '\r\nLocalidad de una vivienda.',
#  '\r\nCambio de nombre de localidad.\r\nLocalidad de dos viviendas.',
#  '\r\nSe conurba a Ojocaliente 0055.',
#  '\r\nHasta este evento estuvo registrada con clave (010010383).',
#  '\r\nA partir de este evento cambia a la clave 010090051.',
#  '\r\nCambio de nombre de localidad.\r\nCambio de categoría política.',
#  'Se conurba a Ojocaliente (0055).',
#  '\r\nLocalidad de dos Viviendas.',
#  '\r\nLocalidad rehabilitada.\r\nLocalidad con dos viviendas.',
#  '\r\nLocalidad rehabilitada.\r\nCambio de categoría política.',
#  '\r\nHasta este evento estuvo registrada con clave (010010317).',
#  '\r\nSe conurba a Pabellón de Arteaga 0001.',
#  ' ',
#  '\r\nHasta este evento estuvo registrada con clave 010050094.',
#  '\r\nA partir de este evento cambia a la clave (010011112).\r\nLocalidad con dos viviendas.',
#  '\r\nCambio de categoría política.',
#  '\r\nHasta este evento estuvo registrada con clave 010090007.',
#  '\r\nLocalidad deshabitada.\r\nCambio de nombre de localidad.',
#  '\r\nA partir de este evento cambia a la clave (010010664).',
#  '\r\nSe conurba a Rincón de Romos 0001.',
#  '\r\nA partir de este evento cambia a la clave 010030386.\r\nCambio de nombre de localidad.',
#  '\r\nHasta este evento estuvo registrada con clave (010010425).',
#  ' \r\nLocalidad rehabilitada.',
#  '\r\nLocalidad rehabilitada.\r\nCambio de nombre de localidad.\r\nLocalidad con una vivienda.',
#  '\r\nHasta este evento estuvo registrada con clave 010030075.',
#  '\r\nSe fusiona a Los Ramírez 0076.',
#  '\r\nLocalidad deshabitada.\r\nLocalidad rehabilitada.',
#  '\r\nLocalidad con una vivienda.\r\nLocalidad deshabitada.',
#  '\r\nLocalidad con dos viviendas.\r\nA partir de este evento cambia a la clave 010050279.',
#  '\r\nHasta este evento estuvo registrada con clave (010010644).',
#  '\r\nLocalidad de dos viviendas.\r\nLocalidad Rehabilitada.',
#  '\r\nA partir de este evento cambia a la clave (010011025).',
#  '\r\nLocalidad rehabilitada.\r\nLocalidad de una vivienda.',
#  '\r\nCambio de categoría política.\r\nHasta este evento estuvo registrada con clave (010010662).',
#  '\r\nLocalidad con Una vivienda.',
#  '\r\nLocalidad conurbada a Jesús María 0001.',
#  '\r\nCambio de nombre de localidad.\r\nCambio de Categoría Política.',
#  '\r\nLocalidad deshabitada.                  Cambio de nombre de localidad.     Se fusiona a  El Moro (0402).',
#  '\r\nA partir de este evento cambia a la clave 010050261.',
#  ' \r\nLocalidad deshabitada.',
#  '\r\nSe conurba a Aguascalientes 0001.',
#  '\r\nCensada con la localidad La Tinaja.',
#  '\r\nSe fusiona a El Bramadero (0611).',
#  '\r\nHasta este evento estuvo registrada con clave 010050138.',
#  '\r\nLocalidad conurbada a Rincón de Romos 0001.',
#  '\r\nSe conurba a Las Cuevas 0005.',
#  '\r\nLocalidad fusionada a Crucero a San José de Gracia (Ejido Progreso) 0352.',
#  '\r\nLocalidad fusionada a Planta Chinoin 0142.',
#  '\r\nLocalidad deshabitada.\r\n',
#  '               Localidad deshabitada.',
#  '\r\nLocalidad deshabitada ',
#  '\r\nA partir de este evento cambia a la clave (010010678).',
#  '\r\nSe fusiona a Barandales de San José (0519).',
#  '\r\nCambio de nombre de localidad.\r\nA partir de este evento cambia a la clave (010010903).',
#  '\r\nLocalidad rehabilitada.\r\nCambio de nombre de localidad.\r\nLocalidad con dos viviendas.',
#  '\r\nPasa al municipio 001 con clave de localidad 2412.',
#  '\r\nSe fusiona a Carboneras 0008.',
#  '\r\nA partir de este evento cambia a la clave 010020213.',
#  '\r\nSe conurba a Calvillo (0001).\r\n',
#  '\r\nLocalidad rehabilitada.\r\nLocalidad deshabitada.',
#  '\r\nLocalidad rehabilitada. Localidad con dos viviendas.',
#  '\r\nLocalidad fusionada a Peña Azul 0423.',
#  '\r\nHasta este evento estuvo registrada con clave 010050075.',
#  '\r\nLocalidad rehabilitada.\r\nLocalidad con una vivienda.\r\nA partir de este evento cambia a la clave (010011092).',
#  '\r\nLocalidad rehabilitada.\r\nLocalidad de una vivienda.\r\nLocalidad deshabitada.\r\nCambio de nombre de localidad.',
#  '\r\nLocalidad Rehabilitada.',
#  '\r\nHasta este evento estuvo registrada con clave 010020057.\r\nLocalidad rehabilitada.\r\nCambio de nombre de localidad.\r\nLocalidad de dos viviendas.',
#  '\r\nLocalidad deshabitada  ',
#  '\r\nHasta este evento estuvo registrada con clave (010010103).',
#  ' Localidad deshabitada.',
#  '\r\nA partir de este evento cambia a la clave (010010815).',
#  '\r\nSe conurba a Calvillo 0001.\r\n',
#  '\r\nHasta este evento estuvo registrada con clave (010010299).',
#  '\r\nSe conurba a Jesús María 0001.',
#  '\r\nLocalidad deshabitada',
#  '\r\n',
#  '\r\n Localidad fusionada a Santa Clara (Las Mieleras) 0100.',
#  '\r\nPasa al municipio Tepezalá 009 con clave 0160.',
#  '                   Baja de Localidad.',
#  '\r\nLocalidad fusionada a San Luis de Letras 0040.',
#  '\r\nLocalidad fusionada a Ninguno 0387.',
#  '\r\nSe fusiona a ninguno 0387.',
#  '\r\nLocalidad fusionada a El Encino 0173.',
#  '\r\nLocalidad rehabilitada.\r\nLocalidad deshabitada.\r\nCambio de nombre de localidad.',
#  '\r\nLocalidad fusionada a El Pedregal 0236.',
#  '\r\nLocalidad fusionada a Mexiquito 0101.',
#  '\r\nSe conurba a Pabellón de Hidalgo 0030.',
#  '\r\nLocalidad fusionada a Sector Agropecuario de la Escuela Secundaria Técnica Numero 11 0372.',
#  '\r\nLocalidad rehabilitada.\r\n',
#  '\r\nSe fusiona a Fracc. Campestre San Carlos 0233.',
#  '\r\nLocalidad  deshabitada.',
#  '\r\nLocalidad deshabitada. ',
#  '\r\nLocalidad deshabitada.\r\n\r\n',
#  '\r\nLocalidad rehabilitada.\r\nCambio de nombre de localidad.\r\nCambio de categoría política.',
#  '\r\nLocalidad rehabilitada.\r\nCambio de categoría política.\r\nLocalidad deshabitada.',
#  '\r\nSe conurba a Pocitos (1025).',
#  '\r\nLocalidad conurbada a Aguascalientes (0001).',
#  '\r\nLocalidad conurbada a Tepezalá 0001.',
#  '\r\nSe fusiona a El Filso (2065).',
#  '\r\nSe fusiona a El Refugio Número Dos [Rancho] 2173.',
#  '\r\nBaja de Localidad.',
#  '\r\nLocalidad fusionada a El Filso (2065).',
#  '              ',
#  ' \r\nLocalidad deshabitada',
#  '\r\nLocalidad fusionada a Sector Noria Blanca 0239.',
#  '\r\nLocalidad rehabilitada.\r\nCambio de nombre de localidad.\r\nLocalidad deshabitada.',
#  '\r\nSe conurba al municipio (011) San Francisco de los Romo localidad (0001).',
#  '            Localidad de dos viviendas.',
#  '\r\nSe fusiona a Pabellón de Arteaga 0001.',
#  '\r\nLocalidad deshabitada\r\n\r\n ',
#  '\r\nPasa al municipio Rincón de Romos 007 con clave 0303.',
#  '\r\nLocalidad rehabilitada.\r\nLocalidad de dos viviendas.',
#  '\r\nPasa al municipio Rincón de Romos 007 con clave 0361.',
#  '\r\nPasa al municipio Rincón de Romos 007 con clave 0320.',
#  '\r\nCambio de nombre de localidad.\r\nA partir de este evento cambia a la clave (010011118).',
#  '\r\nA partir de este evento cambia a la clave (010011102).',
#  '\r\nViene del municipio Asientos (002).',
#  '\r\nViene del municipio Aguascalientes (001).',
#  '\r\nLocalidad conurbada a Palo Alto 0001.',
#  '\r\nPasa al municipio San Francisco de los Romo (011) con clave (0052).\r\nDecreto No. 162 del 30 de enero de 1992.',
#  '\r\nCambio de nombre de localidad.\r\nLocalidad rehabilitada.\r\nLocalidad con una vivienda.',
#  '                              Se fusiona a Granja San José (0055).',
#  '\r\nSe fusiona a San Cristóbal (1085).',
#  '\r\nCambio de nombre de localidad.\r\nA partir de este evento cambia a la clave (010010919).',
#  '\r\nSe fusiona a Licenciado Adolfo López Mateos (0259).',
#  '\r\nBaja de localidad',
#  '\r\nLocalidad rehabilitada.\r\nCambio de nombre de localidad.\r\nLocalidad deshabitada.\r\n\r\n',
#  '\r\nHasta este evento estuvo registrada con clave (010010118).',
#  '\r\nLocalidad deshabitada.  ',
#  '\r\nLocalidad fusionada a Santa Rita 0049.',
#  '\r\nBaja de localidad.\r\nSin Viviendas.',
#  '\r\nSe fusiona a Emiliano Zapata 0007.',
#  '\r\nCambio de nombre de localidad.\r\nA partir de este evento cambia a la clave (010010686).',
#  '\r\nPasa al municipio Pabellón de Arteaga (006) con clave (0264).',
#  '\r\nPasa al municipio Rincón de Romos 007 con clave 0278.',
#  '\r\nPasa al municipio Rincón de Romos 007 con clave 0288.',
#  ' Localidad deshabitada',
#  '\r\nLocalidad deshabitada.\r\nLocalidad rehabilitada.\r\nCambio de nombre de localidad.',
#  '\r\nSe fusiona a Chichihuas (0404).',
#  '\r\nLocalidad rehabilitada.\r\nCambio de nombre de localidad.\r\nLocalidad de una vivienda.',
#  '\r\nSe conurba a Jesús Gómez Portugal (0041).',
#  '\r\nSe conurba a San Francisco de los Romo (0001).',
#  '\r\nHasta este evento estuvo registrada con clave (010010346).',
#  '\r\nCambio de nombre de localidad.\r\nDecreto No. 162 del 30 de enero de 1992.\r\nPasa al municipio El Llano (010) con clave (0104).',
#  '\r\nLocalidad con dos viviendas.\r\nCambio de nombre de localidad.',
#  '\r\nCambio de nombre de localidad.\r\nCambio de categoría política.\r\nHasta este evento estuvo registrada con clave (010010158).',
#  '\r\nLocalidad con una vivienda.\r\nA partir de este evento cambia a la clave 010011015.',
#  '\r\nA partir de este evento cambia a la clave (010011027).',
#  '\r\nBaja de localidad.\r\nRuinas.',
#  '\r\nLocalidad con una vivienda.\r\nA partir de este evento cambia a la clave (010011040).',
#  '\r\nBaja de localidad.\r\nEs parte de la localidad Cables de Arellano.',
#  '\r\nLocalidad con una vivienda.\r\nA partir de este evento cambia a la clave (010011072).',
#  '\r\nBaja de localidad.\r\nVivienda en Ruinas.',
#  '\r\nCambio de nombre de localidad.\r\nA partir de este evento cambia a la clave (010011075).',
#  '\r\nA partir de este evento cambia a la clave (010011076).',
#  '\r\nA partir de este evento cambia a la clave (010011078).',
#  '\r\nHasta este evento estuvo registrada con clave (010010391).',
#  '\r\nHasta este evento estuvo registrada con clave (010010360).',
#  '\r\nHasta este evento estuvo registrada con clave (010010491).',
#  '\r\nPasa al municipio Jesús María (005) con clave (0393).',
#  '\r\nLocalidad con una vivienda.\r\nA partir de este evento cambia a la clave (010012259).',
#  '\r\nSe conurba a Villa Licenciado Jesús Terán (Calvillito) (0479).',
#  '\r\nPasa al municipio El Llano (010) con clave (0147).',
#  '\r\nLocalidad de una vivienda.\r\nCambio de nombre de localidad.',
#  '                    Se fusiona a Charco Prieto (El Palomar) (0093).',
#  '\r\nLocalidad conurbada a Villa Juárez (0059). ',
#  '\r\nLocalidad deshabitada.\r\nLocalidad con una vivienda.',
#  '\r\nLocalidad de una Vivienda.',
#  '\r\nLocalidad conurbada a Calvillo 0001.',
#  '\r\nLocalidad deshabitada.\r\nLocalidad con dos viviendas.',
#  '\r\nLocalidad con dos viviendas.\r\nLocalidad deshabitada.',
#  '\r\nSe conurba a San Antonio de los Horcones 0084.\r\n',
#  '\r\nSe fusiona a Los Sauces 0278.',
#  '\r\nPasa al municipio Pabellón de Arteaga 006 con clave 0260.\r\n',
#  '\r\nA partir de este evento cambia a la clave 010050243.',
#  '\r\nCambio de nombre de localidad.\r\nBaja de localidad.',
#  '\r\nLocalidad de una o dos viviendas.\r\nCambio de nombre de localidad.',
#  '\r\nSe conurba a Jesús Gómez Portugal (Margaritas) 0041.',
#  '\r\nLocalidad deshabitada\r\n',
#  '\r\nLocalidad fusionada a Los Arquitos 0007.',
#  '\r\nLocalidad deshabitada.\r\nCambio de categoría política.',
#  '\r\nSe fusiona a Puerta del Milagro 0031.',
#  ' \r\nLocalidad de dos viviendas.\r\nCambio de nombre de localidad.',
#  '\r\nSe fusiona a Ojo Zarco 0024.',
#  '\r\nPasa al municipio Rincón de Romos 007 con clave 0357.',
#  '\r\nLocalidad de una vivienda.\r\nA partir de este evento cambia a la clave 010060212.',
#  '\r\nPasa al municipio Rincón de Romos 007 con clave 0294.',
#  '\r\nA partir de este evento cambia a la clave 010060235.\r\nLocalidad de dos viviendas.',
#  '\r\nPasa al municipio Rincón de Romos 007 con clave 0312.',
#  '\r\nPasa al municipio Rincón de Romos 007 con clave 0383.',
#  '\r\nPasa al municipio Rincón de Romos 007 con clave 0354.',
#  '\r\nPasa al municipio Rincón de Romos 007 con clave 0408.',
#  '\r\nLocalidad fusionada a Sector de Producción el Jagüey 0373.',
#  '\r\nA partir de este evento cambia a la clave 010070135.\r\nLocalidad de una vivienda.',
#  '\r\nLocalidad fusionada a Lázaro Cárdenas [Fraccionamiento] 0419.',
#  '\r\nBaja de localidad.\r\nCambio de nombre de localidad.',
#  '\r\nBaja de Localidad',
#  '    Se conurba a Tepezalá (0001).',
#  '\r\nSe conurba a San Antonio 0025.',
#  '\r\nPasa al municipio Asientos 002 con clave 0243.',
#  ' Se conurba a Palo Alto (0001).',
#  '\r\nLocalidad deshabitada \r\n',
#  '\r\nViene del municipio Pabellón de Arteaga (006) con clave (0142).\r\nLocalidad deshabitada.\r\n\r\n',
#  '\r\nLocalidad deshabitada.\r\n\r\n.',
#  '\r\nViene del municipio Pabellón de Arteaga (006) con clave (0139). \r\nLocalidad de una vivienda.',
#  '\r\nViene del municipio Pabellón de Arteaga (006) con clave de localidad (0217).\r\nLocalidad de una vivienda.',
#  '\r\nViene del municipio Pabellón de Arteaga (006) con clave (0072).\r\nLocalidad de dos viviendas.',
#  '\r\nViene del municipio Pabellón de Arteaga (006) con clave (0242).\r\nLocalidad de una vivienda.',
#  '\r\nHasta este evento estuvo registrada con clave 010050044.',
#  '\r\nViene del municipio Pabellón de Arteaga (006) con clave (0060).\r\nLocalidad de una vivienda.',
#  '\r\nViene del municipio Pabellón de Arteaga (006) con clave (0244).\r\nLocalidad de una vivienda.',
#  '\r\nViene del municipio Pabellón de Arteaga (006) con clave (0179).\r\nLocalidad de dos viviendas.',
#  '\r\nLocalidad de dos viviendas.\r\nViene del municipio Pabellón de Arteaga (006) con clave (0067).',
#  '\r\nViene del municipio Pabellón de Arteaga (006) con clave (0243).\r\nLocalidad de una vivienda.',
#  '\r\nViene del municipio Pabellón de Arteaga (006) con clave (0245).\r\nLocalidad de una vivienda.',
#  '\r\nLocalidad de dos viviendas.\r\nLocalidad deshabitada.',
#  '\r\nLocalidad de una vivienda.\r\nLocalidad deshabitada.',
#  '\r\nLocalidad conurbada a Asientos (010020001).',
#  '\r\nViene del municipio El Llano (010) con clave (0108).',
#  '\r\nLocalidad dehabitada.',
#  '\r\nHasta este evento estuvo registrada con clave (010010493).',
#  '\r\nHasta este evento estuvo registrada con clave (010010724).',
#  '\r\nHasta este evento estuvo registrada con clave (010010689).',
#  '\r\nHasta este evento estuvo registrada con clave (010010733).',
#  '\r\nHasta este evento estuvo registrada con clave (010010685).',
#  '\r\nHasta este evento estuvo registrada con clave (010010343).',
#  '\r\nHasta este evento estuvo registrada con clave (010010666).',
#  '\r\nHasta este evento estuvo registrada con clave 010010311.',
#  '\r\nViene del municipio Pabellón de Arteaga (006) con clave de localidad (0043).',
#  '\r\nLocalidad con una vivienda.\r\nViene del municipio Asientos (002) con clave (0108).',
#  '\r\nViene del municipio Aguascalientes (001) con clave (0654).',
#  '\r\nViene del municipio Jesús María (005) con clave (0215).',
#  '\r\nHasta este evento estuvo registrada con clave 010070073.',
#  '\r\nHasta este evento estuvo registrada con clave 010060062.',
#  '\r\nHasta este evento estuvo registrada con clave 010060144.',
#  '\r\nLocalidad de una vivienda',
#  '\r\nLocalidad deshabitada\r\n\r\n',
#  '\r\nViene del municipio Aguascalientes (001) con clave (1155).',
#  '         Localidad deshabitada.',
#  '                   Localidad deshabitada.',
#  '                                  ',
#  '                               Localidad deshabitada.',
#  '            Localidad deshabitada.',
#  '                                   Localidad deshabitada.',
#  '                     ',
#  '\r\nLocalidad rehabilitada.           ',
#  '\r\nCambio de nombre de localidad.\r\nLocalidad rehabilitada.',
#  '                           ',
#  '        Localidad deshabitada.',
#  '\r\nLocalidad rehabilitada.\r\nCambio de nombre de localidad.  ',
#  '\r\nCambio de nombre de localidad.  ',
#  '\r\nBaja de localidad. ',
#  '                    Localidad deshabitada.',
#  ' Localidad deshabitada.\r\nCambio de nombre de localidad.',
#  '   Localidad deshabitada.',
#  '\r\nHasta este evento la localidad estuvo registrada con la clave.\r\nA partir de este evento la localidad cambia a la clave 02 003 0931.\r\n',
#  '\r\nCambio de nombre de localidad.\r\nCambio de nombre de localidad.',
#  '                                                      Cambio de nombre de localidad.',
#  '                                      ',
#  '\r\nLocalidad rehabilitada.                   Localidad deshabitada.',
#  '                                 Localidad deshabitada.                                 ',
#  '\r\nCambio de nombre de localidad. ',
#  '                    Cambio de nombre de localidad.',
#  ' Cambio de nombre de localidad.',
#  '                 ',
#  '\r\nLocalidad rehabilitada.                    Localidad deshabitada.',
#  '                                     ',
#  '\r\n Se conurba a Mexicali (0001).',
#  '\r\nCambio de nombre de localidad. Localidad deshabitada.',
#  'Se conurba a Mexicali (0001).',
#  '       Localidad deshabitada.',
#  '\r\nLocalidad rehabilitada.                                     Cambio de nombre de localidad.',
#  '\r\nSe conurba a Tijuana (0001).',
#  '  Cambio de nombre de localidad.',
#  '}\r\nLocalidad deshabitada.',
#  '                                 Localidad rehabilitada.\r\nCambio de nombre de localidad. Localidad deshabitada.',
#  '                     Localidad deshabitada.',
#  '    Localidad rehabilitada.',
#  '                                                    ',
#  '                                  Localidad deshabitada.',
#  '\r\nSe conurba a Mexicali (0001).',
#  '\r\nSe conurba a Querétaro (0268).',
#  '              Localidad deshabitada.',
#  '\r\nLocalidad rehabilitada.\r\nCambio de nombre de localidad. Localidad deshabitada.',
#  '                                    ',
#  ' Baja de localidad.',
#  '\r\nLocalidad rehabilitada.\r\nCambio de nombre de localidad.  Localidad deshabitada.',
#  '\r\nSe conurba a Guadalupe Victoria (Benito Juarez) (0185).',
#  '\r\nLocalidad rehabilitada.  Localidad deshabitada.',
#  '                                                   Cambio de nombre de localidad.',
#  '\r\nCensó con la localidad Sierra de Juárez 020010251. Localidad deshabitada.',
#  '\r\nLocalidad rehabilitada.\r\nViene del municipio Tecate.',
#  '                              ',
#  '\r\nBaja de localidad.\r\nSe conurba a  El Potrerito (0839).',
#  '     Localidad deshabitada.',
#  '\r\nViene del municipio Tijuana. 004 0001.',
#  '\r\n Baja de  localidad.',
#  '\r\nLocalidad rehabilitada.\r\nCambio de nombre de localidad.\r\nLocalidad  deshabitada.',
#  '                 .\r\nCambio de nombre de localidad.',
#  '                                            Localidad deshabitada.',
#  '\r\nLocalidad rehabilitada. Localidad deshabitada.',
#  '                                                 ',
#  '                 Localidad deshabitada.',
#  '\r\nCambio de nombre de localidad.            ',
#  '\r\nLocalidad rehabilitada.\r\nCambio de nombre de localidad.   ',
#  '                    ',
#  '      Localidad deshabitada.',
#  '   Cambio de nombre de localidad',
#  '                            ',
#  '                             Localidad deshabitada.',
#  '  Baja de localidad.',
#  '\r\nViene del municipio Tijuana (004) con clave de localidad (0696).',
#  '                   Cambio de nombre de localidad.',
#  '\r\nCensó con la localidad Guadalupe 020010114. Localidad deshabitada.',
#  '\r\nSe conurba a Delta (Estacion Delta) (0159).',
#  '                                             ',
#  '\r\nSe conurba a Puebla (0262).',
#  '\r\nLocalidad rehabilitada.\r\nViene del municipio Tijuana.',
#  '\r\n\r\nLocalidad rehabilitada.\r\nCambio de nombre de localidad.',
#  '  \r\nCambio de nombre de localidad.',
#  '\r\nCensó con la localidad Santo Tomás 020010242. Localidad deshabitada.',
#  '\r\nViene del municipio Tecate 003.',
#  '\r\nViene del municipio Tijuana (004) con clave de localidad  (0730).',
#  '\r\nLocalidad rehabilitada.\r\nCambio de nombre de localidad. ',
#  '           \r\nLocalidad rehabilitada.      ',
#  '\r\nSe conurba a Benito Juárez (Tecolotes) (0456).',
#  '\r\nSe conurba a  Paredones (0456).',
#  '\r\nSe conurba a Benito Juárez Tecolotes (0456).',
#  '\r\nSe conurba a Paredones (0459).',
#  '\r\nSe conurba a  Guadalupe Victoria (0185).',
#  '\r\nCensó con la localidad la Calentura 020010059.',
#  '    Localidad deshabitada.',
#  '\r\nCambio de nombre de localidad.\r\nLocalidad rehabilitada.                   Localidad deshabitada.',
#  '                                                     Localidad deshabitada.',
#  '\r\nViene del municipio Tijuana clave 02004.\r\nLocalidad deshabitada.',
#  '                                         ',
#  '\r\nBaja de localidad.                                                             Cambio de nombre de localidad.',
#  '                        ',
#  '.\r\nCambio de nombre de localidad. ',
#  '                         Cambio de nombre de localidad.                                         ',
#  '\r\nCambio de nombre de localidad.   ',
#  '\r\nViene del municipio Tecate (003) con clave de localidad (0029).',
#  '                                           ',
#  '\r\nCambio de nombre de localidad.   Localidad rehabilitada.',
#  '                                   ',
#  '\r\nCenso en la Ciudad de Ensenada. Localidad deshabitada.',
#  '\r\nCensó con la localidad Real del Castillo 020010190.                            Localidad deshabitada.',
#  '                                     Localidad deshabitada.',
#  '                                               Localidad deshabitada.',
#  '\r\nLocalidad rehabilitada.\r\nCambio de nombre de localidad.\r\nCensó con la localidad Sierra de Juárez 020010251. Localidad deshabitada.',
#  '\r\nCambio de nombre de localidad',
#  '                                          Localidad deshabitada.',
#  '                                           Localidad deshabitada.',
#  '                                         \r\nLocalidad deshabitada.',
#  '  Localidad deshabitada.',
#  '\r\nCambio de nombre de localidad.\r\nLocalidad deshabitada.\r\n',
#  '                                              Localidad deshabitada.',
#  '                                         Localidad deshabitada.',
#  '                                                  Localidad deshabitada.',
#  '                                                Localidad deshabitada.',
#  '\r\nCambio de nombre de localidad.\r\nViene del municipio Ensenada.',
#  '                                                \r\nLocalidad deshabitada.',
#  '  \r\nLocalidad deshabitada.',
#  '                                          \r\nLocalidad deshabitada.',
#  '                   Cambio de nombre de localidad.  ',
#  '                                             Localidad deshabitada.',
#  '                                        Localidad deshabitada.',
#  '\r\nCensó con la localidad Ensenada 020010001.',
#  '                                      Localidad deshabitada.',
#  '                        Cambio de nombre de localidad. ',
#  '                                    Localidad deshabitada.',
#  ' \r\nCambio de nombre de localidad.',
#  '             Localidad deshabitada.',
#  ' Cambio de nombre de localidad',
#  '                Localidad deshabitada.',
#  '        Cambio de nombre de localidad.',
#  '          Localidad deshabitada.',
#  '\r\nViene del municipio Tijuana (004) con clave de localidad (0673).\r\nLocalidad deshabitada.',
#  '            Cambio de nombre de localidad',
#  '  Localidad rehabilitada.',
#  '\r\nSe conurba a Ensenada (0001).',
#  '\r\nLocalidad rehabilitada.              Cambio de nombre de localidad.',
#  '                  Localidad deshabitada.',
#  '                                              ',
#  '\r\nViene del municipio Ensenada 001.',
#  '\r\nViene del municipio Tecate clave 02003.',
#  '\r\nLocalidad rehabilitada.\r\nCambio de nombre de localidad.\r\nViene del municipio Tecate (003) con clave de localidad (0730). \r\nCambio de categoría política.',
#  '                                                     ',
#  '\r\nLocalidad rehabilitada.\r\nCambio de nombre del municipio.',
#  '\r\nSe conurba a Rosarito (0223).',
#  '    Cambio de nombre de localidad.',
#  '                                                ',
#  '   Cambio de nombre de localidad.',
#  '              Cambio de nombre de localidad.',
#  '                                                  ',
#  '                        Localidad deshabitada.',
#  '       Cambio de nombre de localidad.',
#  '      Cambio de nombre de localidad.',
#  '                                            ',
#  '\r\nViene del municipio Tijuana (004) con clave de localidad  (0713).',
#  '                                          ',
#  '\r\nViene del municipio Ensenada.',
#  '\r\nViene del municipio Tecate.  ',
#  '\r\nCambio de nombre de localidad.\r\nViene del municipío Tecate (003) con clave de localidad (0696).',
#  '\r\nLocalidad rehabilitada.         ',
#  '\r\nViene del municipio Tecate.',
#  '\r\nCensó con la localidad San Vicente 020010243.',
#  '                                                   ',
#  '                                               ',
#  '\r\n Localidad deshabitada.',
#  '                                                \r\n',
#  '\r\nCambio de nombre de localidad.\r\nLocalidad rehabilitada.\r\nViene del municipio Tijuana (004) con clave de localidad (0318). \r\nLocalidad deshabitada.',
#  '\r\nCambio de nombre de localidad.                                      ',
#  '\r\nLocalidad rehabilitada.\r\nCambio de nombre de localidad.\r\nViene del municipio Tecate clave 02003.',
#  '\r\nLocalidad rehabilitada.\r\nCambio de nombre del municipio.\r\nCambio de categoría política.',
#  ' Se conurba a Guadalupe Victoria (Kilometro 43) ( 0185).',
#  '\r\nLocalidad rehabilitada.                    ',
#  '\r\nCambio de nombre de localidad.\r\nA partir de este evento la localidad cambia a la clave 003 0334.',
#  '                                        ',
#  '\r\nDocumento. S/n.\r\nViene del municipio Tijuana.\r\nLocalidad deshabitada.',
#  '\r\nBaja de localidad.  \r\nCambio de nombre de localidad.',
#  '\r\nLocalidad deshabitada. \r\nCambio de nombre de localidad.',
#  '\r\nCambio de nombre de localidad.\r\nViene del municipio Tecate (003) con clave de localidad  (0215).',
#  '\r\nCambio de nombre de localidad.    ',
#  '\r\nLocalidad rehabilitada.\r\nCambio de nombre de localidad',
#  '\r\nCambio de nombre de localidad.\r\n',
#  '\r\nViene del municipio Tecate. 003 0001.',
#  '\r\nA partir de este evento la localidad cambia a la clave 003 0106.',
#  '\r\nCensó con la localidad Santa Catarina 020010232.',
#  ' Localidad deshabitada.          Localidad rehabilitada ',
#  '\r\nCambio de nombre de localidad.\r\nA partir de este evento cambia a la clave 020021400.',
#  '\r\nSe conurba a Mexicali 0001.',
#  '\r\nCambio de categoría política.\r\nCambio de nombre de localidad.',
#  '                                Cambio de nombre de localidad.          ',
#  '                                ',
#  '  \r\n',
#  '                                       ',
#  '\r\nLocalidad rehabilitada.\r\nCambio de nombre de localidad.\r\nCambio de nombre de la sección municipal.',
#  '\r\nLocalidad deshabitada.\r\nCambio de nombre de localidad.\r\nCambio de categoría política.',
#  '\r\nLocalidad rehabilitada.\r\nCambio de nombre de localidad.\r\nViene de la sección municipal de San Telmo.',
#  '                                      Cambio de nombre de localidad.',
#  '\r\nLocalidad Rahabilitada.',
#  '\r\nLocalidad rehabilitada.                                Cambio de nombre de localidad.      ',
#  ' \r\n                                     ',
#  '\r\nLocalidad rehabilitada.\r\nViene del municipio Tijuana (004) con clave de localidad (0044). \r\nLocalidad deshabitada.',
#  '\r\nLocalidad deshabitada.\r\nLocalidad deshabitada.\r\n',
#  '                               Cambio de nombre de localidad.                                      ',
#  '\r\nCambio de nombre del municipio.',
#  '                              \r\nLocalidad deshabitada.                               Cambio de nombre de localidad.',
#  '\r\nLocalidad rehabilitada.\r\nCambio de nombre de la sección municipal.\r\nLocalidad deshabitada.',
#  '\r\nViene de la sección municipal de San Telmo.\r\nCambio de categoría política.',
#  '\r\nLocalidad rehabilitada.\r\nCambio de nombre de localidad.\r\nCambio de categoría política.\r\nLocalidad deshabitada.',
#  '\r\nSe conurba a Lázaro Cárdenas (Valle de la Trinidad) (0935).',
#  '\r\nCambio de nombre del municipio.\r\nCambio de categoría política.',
#  '\r\nViene del municipio Tijuana con clave 004.\r\nLocalidad deshabitada.',
#  '\r\nCambio de nombre de la sección municipal.',
#  '\r\nViene de la sección municipal de Calnali.',
#  '\r\nLocalidad rehabilitada.\r\nHasta este evento la localidad estuvo registrada con la clave 003 0239.',
#  '\r\nCambio de nombre de localidad.\r\nCambio de nombre de la sección municipal.\r\nCambio de categoría política.',
#  '\r\nCambio de nombre de la sección municipal.\r\nCambio de categoría política.',
#  '\r\nLocalidad Rehabilitada. Localidad deshabitada.  ',
#  '\r\nSe conurba a Santa Isabel (0289).',
#  '\r\nCambio de nombre de localidad.\r\nViene de la sección municipal de Calnali.\r\nCambio de categoría política.',
#  '\r\nViene del municipio Tijuana 004.',
#  '             Cambio de nombre de localidad.',
#  '\r\nLocalidad rehabilitada.       ',
#  '\r\nLocalidad rehabilitada.\r\nCambio de nombre de localidad.\r\nA partir de este evento cambia a la clave 020021413.',
#  '\r\nLocalidad rehabilitada.\r\nCambio de nombre de la sección municipal.',
#  '\r\nLocalidad rehabilitada.        Localidad deshabitada.',
#  '                                             \r\n',
#  '        ',
#  '\r\nCambio de nombre de localidad.\r\nCambio de nombre del municipio.',
#  '                          Cambio de nombre de localidad.\r\nLocalidad deshabitada.',
#  '\r\nLocalidad rehabilitada.        ',
#  '\r\nSe conurba a la Joya (0187).',
#  '\r\nCensó con la localidad El Marmol 020010142.',
#  '\r\nLocalidad rehabilitada.\r\nCambio de nombre del municipio.\r\nLocalidad deshabitada.',
#  '\r\nLocalidad rehabilitada.\r\nCambio de nombre de sección municipal.',
#  '\r\nCambio de nombre de localidad.  Localidad deshabitada.',
#  '  ',
#  '\r\nCensó con la localidad El Sauzal 020010247.',
#  '\r\nPasa al municipio Tecate (003) con clave de localidad (0606).',
#  '\r\nPasa al municipio Tecate (003) con clave de localidad (0173).',
#  '\r\nViene del municipio Tecate (003) con clave de localidad (0083).',
#  '\r\nViene del municipio Tijuana.',
#  '\r\nViene del municipio Tijuana (004)con clave de localidad  (0732).',
#  '\r\nSe conurba a Primo Tapia (0216). ',
#  '\r\nBaja de localidad a.',
#  '  \r\nCambio de nombre de localidad.\r\nLocalidad rehabilitada.',
#  '\r\nLocalidad rehabilitada.\r\nViene de la sección municipal San Quintin.',
#  ' \r\nCambio de nombre de localidad. Localidad deshabitada.',
#  '\r\nLocalidad deshabitada.          Cambio de nombre de localidad.',
#  'Se conurba a Playas de Rosarito (0001).',
#  '\r\nViene del municipio Tijuana (003) con clave de localidad (0669).\r\nLocalidad deshabitada.',
#  '\r\nCambio de nombre de localidad.\r\nViene del municipio Tecate clave 02003.',
#  '\r\nLocalidad rehabilitada.\r\nViene del municipio Tecate (003) con  clave de localidad (0098).',
#  '\r\nViene del municipio Tijuana clave 02004.\r\nCambio de categoría política.',
#  '\r\nViene del municipio Tijuana con clave 02 004 0820.\r\nLocalidad deshabitada.',
#  '\r\nCambio de nombre de localidad.\r\nCambio de categoría de la localidad.',
#  '\r\nLocalidad rehabilitada.        Cambio de nombre de localidad.',
#  ' \r\n',
#  '\r\nLocalidad rehabilitada.                     Cambio de nombre de localidad.',
#  '\r\nViene del municipio Tijuana (004) con clave de localidad (0790).',
#  '\r\nViene del municipio Tijuana (004) con clave  de localidad (0001).',
#  '\r\nViene del Municipio los Algodones Loc. 0111 Municipio 002.\r\nCambio de categoría política.',
#  '\r\nLocalidad rehabilitada.\r\nLocalidad deshabitada.\r\nHasta este evento la localidad estuvo registrada con la clave 003 0198.',
#  '\r\nHasta este evento estuvo registrada con clave 020020220.',
#  '\r\nCensó con la localidad de Ensenada 020010001.   Localidad deshabitada.',
#  '\r\nCensó con la localidad Ensenada 020010001.                    Localidad deshabitada.',
#  '\r\nLocalidad rehabilitada.\r\nCambio de nombre de la Localiddad.',
#  '\r\nViene del municipio los Algodones Loc. 0111 del Municipio 002.\r\nCambio de categoría política.',
#  '\r\nLocalidad rehabilitada.\r\nCambio de categoría política.\r\nCambio de nombre de localidad.',
#  '\r\nLocalidad rehabilitada.\r\nA partir de este evento cambia a la clave 020021406.',
#  '                                                    \r\nA partir de este evento cambia a la clave 020022945.',
#  '\r\nCensó con la localidad Real del Castillo 020010190. Localidad deshabitada.',
#  '\r\nCambio de nombre de localidad.\r\nCambio de nombre de la sección municipal.',
#  '\r\nCensó con la localidad Rosario de Abajo 020010198.                    Localidad deshabitada.',
#  '\r\nCambio de nombre de localidad.\r\nViene de la sección municipal de El Alamo.',
#  '                                                   Localidad deshabitada.',
#  '\r\nViene de la sección municipal de Ensenada de Todos Santos.',
#  '\r\nCambio de nombre de localidad.\r\nViene de la sección municipal de Ensenada de Todos Santos.\r\nCambio de categoría política.',
#  '\r\nCambio de nombre de localidad.\r\nViene de la sección municipal de Ensenada de Todos Santos.',
#  '\r\nViene de la sección municipal Real del Castillo.',
#  ' Localidad deshabitada.\r\n ',
#  '          Cambio de nombre de localidad.',
#  '\r\nCambio de nombre de localidad.\r\nCambio de nombre del municipio.\r\nCambio de categoría política.',
#  '\r\nCensó en la Congregación San Vicente.  Localidad deshabitada.',
#  '            Cambio de nombre de localidad.                     ',
#  '\r\nLocalidad deshabitada.\r\nLocalidad deshabitada.',
#  '\r\nCambio de categoría política.\r\nLocalidad deshabitada.',
#  ' \r\nCambio de nombre de localidad.\r\nLocalidad deshabitada.',
#  '\r\nPasa al municipio Tecate (003) con clave de localidad (0703).',
#  '\r\nPasa al municipio Tecate (003) con clave de localidad (0321).',
#  '\r\nPasa al municipio Tecate (003) con clave de localidad (0314).',
#  '\r\nPasa al municipio Tecate (003) con clave de localidad (1139).',
#  '  Localidad deshabitada. \r\nCambio de nombre de localidad.',
#  '\r\nLocalidad deshabitada.\r\nCambio de nombre de localidad.\r\n',
#  '\r\nLocalidad deshabitada.         Cambio de nombre de localidad.',
#  '    Cambio de nombre de localidad',
#  '\r\nLocalidad deshabitada.                 Cambio de nombre de localidad.',
#  '                           Cambio de nombre de localidad.     Localidad deshabitada.',
#  '                                                              Cambio de nombre de localidad.',
#  '                                                          Localidad deshabitada.',
#  '\r\nViene del Municipio Ensenada de Todos Santos Loc. 0001 Municipio 001.',
#  '\r\nViene del municipio Ensenada de Todos Santos Loc. 0001 Municipio 001.',
#  '\r\nViene del municipio Ensenada de Todos Santos Loc 0001 del Municipio 001.\r\nCambio de categoría política.',
#  '\r\nViene del municipio Los Algodones Loc. 0111 del Municipio 002.',
#  ' Se conurba a Mexicali (0001).',
#  '\r\nSe fusiona a Mariana (0218).',
#  '          Se conurba a Santa Isabel (0289).',
#  '\r\nSe fusionó con la localidad colonia Miguel Alemán 1369.',
#  '\r\nHasta este evento estuvo registrada con clave 020021304.',
#  '\r\nSe fusiona a José María Rodríguez (La Panga) (0311).',
#  '\r\nCambio de nombre de localidad.Localidad deshabitada.',
#  '  Cambio de nombre de localidad.                   Localidad deshabitada.',
#  '            Cambio de nombre de localidad.',
#  '\r\n  Cambio de nombre de localidad.',
#  '                            Cambio de nombre de localidad.       Localidad deshabitada.',
#  '                                           Cambio de nombre de localidad.                     Localidad deshabitada.',
#  '                                 Cambio de nombre de localidad.  Localidad deshabitada.',
#  '       Cambio de nombre de localidad',
#  '\r\n   Cambio de nombre de localidad.',
#  '                        Cambio de nombre de localidad.',
#  '                                Cambio de nombre de localidad.',
#  '\r\nLocalidad deshabitada.   Cambio de nombre de localidad.',
#  '\r\nLocalidad deshabitada.      Cambio de nombre de localidad.',
#  '                                                                         Localidad deshabitada.',
#  '\r\nViene del municipio Ensenada de Todos Santos.',
#  '\r\nCambio de nombre de localidad.\r\nViene del municipio Ensenada de Todos Santos con clave 02 003 0029.',
#  '\r\nViene del municipio Ensenada de Todos Santos con clave 02 001 0068.',
#  '\r\nViene del municipio Ensenada de Todos Santos con clave 02 001 0083.',
#  '\r\nCambio de nombre de localidad.\r\nViene del municipio Tecate (003) con  clave de localidad  (0107).\r\nCambio de categoría política.\r\nCambio de nombre de localidad.',
#  '\r\nViene del municipio Ensenada clave 02001.',
#  '\r\nViene del municipio Ensenada de Todos Santos clave 02001.',
#  '\r\nViene del municipio Ensenada de Todos Santos clave 02001.\r\nCambio de nombre de localidad.',
#  '\r\nCambio de nombre de localidad.\r\nA partir de este evento la localidad cambia a la clave 02 003 0934.',
#  '\r\nCambio de nombre de localidad.\r\nViene del municipio Ensenada de Todos Santos.',
#  '\r\nA partir de este evento la localidad cambia a la clave 02 003 0256.',
#  '\r\nPasa al municipio Ensenada (001) con clave de localidad (2037).',
#  '\r\nBaja de localidad.            Cambio de nombre de localidad.',
#  '\r\nViene del municipio Ensenada de Todos Santos con clave 02 001 0696.',
#  '                               Cambio de nombre de localidad.',
#  '\r\nViene del municipio Ensenada de Todos Los Santos. con clave 02 001 0730.\r\nCambio de nombre de localidad.',
#  '                              Cambio de nombre de localidad.',
#  '\r\nViene del municipio Ensenada (001) con clave de localidad (0753).',
#  '\r\nBaja de localidad.                 Cambio de nombre de localidad.',
#  '\r\nMisma Loc. que la 0230 Encinal',
#  '                                   Cambio de nombre de localidad.\r\n',
#  '\r\nViene del municipio Ensenada (001) con clave de localidad (2038).\r\n Localidad deshabitada.',
#  '\r\nBaja de localidad.                   Cambio de nombre de localidad.',
#  '\r\nLocalidad deshabitada.                     Cambio de nombre de localidad.',
#  '\r\nLocalidad deshabitada.       Cambio de nombre de localidad.',
#  '                                                                               Localidad deshabitada.',
#  '\r\nPasa al municipio Tijuana.',
#  '\r\nPasa al municipio Tecate.',
#  '\r\n Viene del municipio Ensenada de Todos Santos.',
#  '\r\nViene del municipio Ensenada.  ',
#  '     ',
#  '\r\nPasa al municipio Tijuana 004.',
#  '\r\nSe conurba a San Luis (0283).',
#  '\r\nCambio de nombre de localidad.\r\nViene del municipio Ensenada 001.',
#  '\r\nSe conurba a  Rosarito (0223).',
#  '\r\n Se conurba a  Rosarito (0223). ',
#  '\r\nViene del municipio Ensenada de Todos Santos.                                 Cambio de nombre de localidad.',
#  'Se conurba a Tijuana (0001).',
#  'Se conurba a Rosarito (0223).',
#  'Se conurba a  Rosarito (0223).',
#  '                Se conurba a Tijuana (0001).',
#  '\r\nSe conurba a Playas de Rosarito (0001). ',
#  ' Se conurba a Playas de Rosarito (0001). ',
#  'Se conurba a Playas de Rosarito (0001). ',
#  '\r\nSe conurba a Playas de Rosarito (0001).',
#  '                                                            Localidad deshabitada.',
#  '                                                  Cambio de nombre de localidad.',
#  '                                                               Localidad deshabitada.',
#  '                                                                          Localidad deshabitada.',
#  '                                                              Localidad deshabitada.',
#  '                                                                             Localidad deshabitada.',
#  '                                                                           Localidad deshabitada.',
#  '                                                                        Localidad deshabitada.',
#  '                                                                           Cambio de nombre de localidad.',
#  '                                 ',
#  '                               ',
#  '                                         \r\n',
#  '                                              \r\n',
#  '                                          \r\n',
#  '                                       \r\n',
#  ' Localidad deshabitada. ',
#  '\r\nLey Orgánica de la Administración Pública Municipal del Estado de B.C. del 30 de septiembre de 1989. Aplicado en 2005.\r\nViene del municipio Playas de Rosarito (005) con clave de localidad (0027).',
#  '\r\nLey Orgánica de la Administración Pública Municipal del Estado de B.C. del 30 de septiembre de 1989. Aplicado en 2005.\r\nViene del municipio Tijuana (004) con clave de localidad (1027).',
#  '\r\nLey Orgánica de la Administración Pública Municipal del Estado de B.C. del 30 de septiembre de 1989. Aplicado en 2005.\r\nViene del municipio Tijuana (004) con clave de localidad (0412).',
#  '\r\nLey Orgánica de la Administración Pública Municipal del Estado de B.C. del 30 de septiembre de 1989. Aplicado en 2005.\r\nViene del municipio Tijuana (004) con clave de localidad (0212).',
#  '\r\nLey Orgánica de la Administración Pública Municipal del Estado de B.C. del 30 de septiembre de 1989. Aplicado en 2005.\r\nViene del municipio Tecate (003) con clave de localidad (1428).',
#  '\r\nLey Orgánica de la Administración Pública Municipal del Estado de B.C. del 30 de septiembre de 1989. Aplicado en 2005.\r\nViene del municipio Tecate (003) con clave de localidad (1140).',
#  '\r\nLey Orgánica de la Administración Pública Municipal del Estado de B.C. del 30 de septiembre de 1989. Aplicado en 2005.\r\nViene del municipio Tecate (003) con clave de localidad (0173).',
#  '\r\nLey Orgánica de la Administración Pública Municipal del Estado de B.C. del 30 de septiembre de 1989. Aplicado en 2005.\r\nViene del municipio Tecate (003) con clave de localidad (0732).',
#  '\r\nLey Orgánica de la Administración Pública Municipal del Estado de B.C. del 30 de septiembre de 1989. Aplicado en 2005.\r\nViene del municipio Tecate (003) con clave de localidad (0204).',
#  '\r\nLocalidad deshabitada.\r\nLey Orgánica de la Administración Pública Municipal del Estado de B.C. del 30 de septiembre de 1989. Aplicado en 2005.\r\nViene del municipio Mexicali (002) con clave de Localidad (3123).',
#  '\r\nLocalidad deshabitada.                    ',
#  '\r\nCensó con la localidad San Vicente 020010243.  Localidad deshabitada.',
#  '\r\nLey Orgánica de la Administración Pública Municipal del Estado de B. C. del 30 de septiembre de 1989. Aplicado en 2005.\r\nViene del municipio Tijuana (004) con clave de localidad (0403).',
#  '\r\nLey Orgánica de la Administración Pública Municipal del Estado de B. C. del 30 de septiembre de 1989. Aplicado en 2005.\r\nViene del municipio Tijuana (004) con clave de localidad (0532).',
#  '\r\nLey Orgánica de la Administración Pública Municipal del Estado de B. C. del 30 de septiembre de 1989. Aplicado en 2005.\r\nViene del municipio Tijuana (004) con clave de localidad (1327).',
#  '\r\nLey Orgánica de la Administración Pública Municipal del Estado de B. C. del 30 de septiembre de 1989. Aplicado en 2005.\r\nViene del municipio Tijuana (004) con clave de localidad (1478).',
#  '\r\nLey Orgánica de la Administración Pública Municipal del Estado de B. C. del 30 de septiembre de 1989. Aplicado en 2005.\r\nViene del municipio Tijuana (004) con clave de localidad (1496).',
#  '                      Localidad deshabitada.',
#  '\r\nPasa a la sección municipal de Ensenada.',
#  '\r\nPasa a la sección municipal de San Telmo.',
#  '                         Localidad deshabitada.',
#  '\r\nPasa al municipio  Playas de Rosarito (005) con clave de localidad (0139). Localidad deshabitada.',
#  '                       Localidad deshabitada.',
#  '\r\nPasa a la sección municipal de Calnali.',
#  '                       ',
#  '\r\nPasa a la sección municipal de El Alamo.',
#  '\r\nSe conurba a Tijuana (0001). Localidad deshabitada.',
#  '\r\nSe conurba a Tijuana (0001).        Localidad deshabitada.',
#  '\r\nSe conurba a Tijuana (0001).         Localidad deshabitada.',
#  '           Localidad deshabitada.',
#  '\r\nHasta este evento estuvo registrada con clave 020020398.',
#  '\r\nLocalidad deshabitada.\r\nLey Orgánica de la Administración Pública Municipal del Estado de B.C. del 30 septiembre de 1989. Aplicado en 2005.\r\nViene del municipio Ensenada (001) con clave de localidad (0822). Localidad deshabitada.',
#  '\r\nLocalidad deshabitada.\r\nLey Orgánica de la Administración Publica Municipal del Estado de B.C. del 30 de septiembre de 1989. Aplicado en 2005.\r\nViene del municipio Ensenada (001) con clave de localidad (1254). Localidad deshabitada.',
#  '\r\nLocalidad deshabitada.\r\nLey Orgánica de la Administración Pública Municipal del Estado de B.C. del 30 de septiembre de 1989. Aplicado en 2005.\r\nViene del municipio Ensenada (001) con clave de localidad (1553). Localidad deshabitada.',
#  '\r\nLocalidad deshabitada.\r\nLey Orgánica de la Administración Pública Municipal del Estado de B.C. del 30 de septiembre de 1989. Aplicado en 2005.\r\nViene del municipio  Ensenada (001) con clave de localidad (1554).',
#  '\r\nLey Orgánica de la Administración Pública Municipal del Estado de B.C. del 30 de septiembre de 1989. Aplicado en 2005.\r\nViene del municipio Ensenada (001) con clave de localidad (3101).',
#  '\r\nLocalidad deshabitada.\r\nLey Orgánica de la Administración Pública Municipal del Estado de B.C. del 30 de septiembre de 1989. Aplicado en 2005.\r\nViene del municipio Ensenada (001) con clave de localidad (3386).',
#  '\r\nLey Orgánica de la Administración Pública Municipal del Estado de B.C. del 30 de septiembre de 1989. Aplicado en 2005.\r\nViene del municipio Ensenada (001) con clave de localidad (3402).',
#  '\r\nLey Orgánica de la Administración Pública Municipal del Estado de B.C. del 30 de septiembre de 1989. Aplicado en 2005.\r\nViene del municipio Ensenada (001) con clave de localidad (4117).',
#  '\r\nLocalidad deshabitada.\r\nLey Orgánica de la Administración Pública Municipal del Estado de B.C. del 30 de septiembre de 1989. Aplicado en 2005.\r\nViene del municipio Ensenada (001) con clave de localidad (4118).',
#  '\r\nLocalidad deshabitada.\r\nLey Orgánica de la Administración Pública Municipal del Estado de B.C. del 30 de septiembre de 1989. Aplicado en 2005.\r\nViene del municipio Ensenada (001) con clave de localidad (4132).',
#  '\r\nLey Orgánica de la Administración Pública Municipal del Estado de B.C. del 30 de septiembre de 1989. Aplicado en 2005.\r\nViene del municipio Tecate (003) con clave de localidad (0605).',
#  '\r\nLey Orgánica de la Administración Pública Municipal del Estado de B.C. del 30 de septiembre de 1989. Aplicado en 2005.\r\nViene del municipio Tecate (003) con clave de localidad (0824).',
#  '\r\nLocalidad deshabitada.\r\nLey Orgánica de la Administración Pública Municipal del Estado de B.C. del 30 de septiembre de 1989. Aplicado en 2005.\r\nViene del municipio Ensenada (001) con Clave de Localidad (1161).',
#  '\r\nCensó con la localidad San Vicente 020010243. Localidad deshabitada.',
#  '                                                 Localidad deshabitada.',
#  '                                                         Localidad deshabitada.',
#  '\r\nLey Orgánica de la Administración Pública Municipal del Estado de B. C. del 30 de septiembre de 1989. Aplicado en 2005.\r\nViene del municipio Tecate (003) con clave de localidad (0005).',
#  '\r\nLey Orgánica de la Administración Pública Municipal del Estado de B. C. del 30 de septiembre de 1989. Aplicado en 2005.\r\nViene del municipio Tecate (003) con clave de localidad (0026).\r\nCambio de nombre de localidad.',
# ...
#  '\r\nDecreto No. 146 del 22 de mayo de 1998. Aplicado en 2005.\r\nViene del municipio Playas de Rosarito (005) con clave de localidad (0128).',
#  '\r\nDecreto No. 146 del 22 de mayo de 1998. Aplicado en 2005.\r\nViene del municipio Playas de Rosarito (005) con clave de localidad (0131).\r\nCambio de nombre de localidad.',
#  '\r\nHasta este evento la localidad estuvo registrada con la clave 02 003 0230.',
#  '\r\nHasta este evento la localidad estuvo registrada con la clave 02 003 0062.',
#  '\r\nAlta de localidad.',
#  '\r\n Actualización Geoestadística del 25 de mayo 2021. \r\n Se conurba a San José del Cabo (0001).\r\n',
#  ' \r\nCambio de categoría política de la localidad.',
#  '\r\nLocalidad  deshabitada',
#  '\r\n Cambio de nombre de localidad. Localidad deshabitada.',
#  ' \r\nCambio de categoría política de la localidad. \r\n',
#  '\r\nCambio de categoría política de la localidad. \r\n',
#  '\r\n Cambio de nombre de localidad.',
#  '\r\n Cambio de categoría política de la localidad.',
#  ' \r\nCambio de nombre de localidad. ',
#  '\r\n ',
#  '\r\nCambio de  nombre de localidad.',
#  '\r\nCambio de categoría política de la localidad.',
#  '\r\n\r\n',
#  '\r\nCambio de nombre de localidad. \r\nLocalidad deshabitada.',
#  ' \r\nCambio de nombre de la localidad',
#  '\r\nLocalidad rehabilitada.\r\n Cambio de nombre de localidad. Localidad deshabitada.',
#  '\r\n Cambio de nombre de localidad. ',
#  '\r\nCambio de nombre de localidad.\r\nCambio de categoría política de la localidad.',
#  '\r\nCambio de nombre de la localidad. ',
#  ' \r\n ',
#  '\r\nBaja de localidad.\r\n',
#  '\r\nCambio de nombre de localidad.\r\n ',
#  '\r\n Localidad deshabitada.\r\nCambio de nombre de localidad. ',
#  '  \r\nLocalidad deshabitada',
#  ' \r\n\r\n',
#  ' \r\nLocalidad rehabilitada. \r\nCambio de nombre de localidad. \r\nLocalidad deshabitada.',
#  ' \r\nCambio de categoría política de la localidad.\r\n',
#  '\r\nCambio de categoría política de la localidad.\r\n',
#  ' \r\nLocalidad rehabilitada. ',
#  ' \r\nCambio de nombre localidad.',
#  '\r\nLocalidad rehabilitada. \r\nLocalidad deshabitada.',
#  '\r\n Localidad deshabitada. \r\n',
#  ' \r\nCambio de nombre de la localidad. ',
#  '\r\n Cambio de nombre de  la localidad. ',
#  '\r\nCambio de nombre de localidad.\r\n\r\n',
#  ' \r\nCambio de nombre de la localidad.',
#  '\r\nBaja de localidad.\r\nMisma localidad que la 0444.',
#  '\r\nCambio de nombre de la localidad.',
#  '\r\n Cambio de categoría política de la localidad. ',
#  ' \r\nLocalidad rehabilitada. \r\nCambio de nombre de localidad. \r\n',
#  '\r\n Baja de localidad.',
#  '\r\n Cambio de nombre de localidad. Baja de localidad.',
#  '\r\n Localidad rehabilitada.\r\nCambio de nombre de localidad.',
#  '\r\nLocalidad rehabilitada',
#  '\r\nLocalidad rehabilitada.\r\nLocalidad deshabitada.\r\n',
#  '\r\n Cambio de categoría política de la localidad.\r\n',
#  ' \r\nCambio de nombre de localidad.\r\n\r\n',
#  '\r\n Localidad Rehabilitada. \r\nLocalidad deshabitada.',
#  ' \r\nViene del municipio La Paz.',
#  '\r\n Localidad rehabilitada.',
#  '\r\nLocalidad rehabilitada. \r\nCambio de nombre de la localidad.',
#  '\r\n Cambio de nombre de la localidad.',
#  '\r\nEsta localidad anteriormente tenía la clave 0135.',
#  '\r\nCambio de categoría política de la localidad.\r\nlocalidad deshabitada.',
#  '\r\n Localidad rehabilitada. ',
#  ' \r\nLocalidad deshabitada. \r\nCambio de nombre de localidad.',
#  ' \r\nCambio de nombre de localidad.\r\nLocalidad rehabilitada. ',
#  '\r\nCambio de nombre la localidad.',
#  '\r\n Localidad rehabilitada. \r\nCambio de nombre de localidad.',
#  ' \r\nLocalidad rehabilitada. \r\nCambio de nombre de localidad. ',
#  '\r\nLocalidad rehabilitada.\r\nLocalidad  deshabitada.',
#  ' \r\n Localidad deshabitada',
#  '\r\n Cambio de categoría política de la localidad. \r\nDecreto No. 62 de la Ley Orgánica Municipal Reglamentaria del titulo Octavo Constitucional. 31 de diciembre 1976.',
#  '\r\nCambio de nombre localidad.',
#  ' \r\nCambio de nombre de localidad.\r\n',
#  '\r\nLocalidad Rehabilitada. \r\nLocalidad deshabitada.',
#  ' \r\nBaja de localidad.',
#  '\r\nCambio de nombre localidad. \r\nLocalidad deshabitada.',
#  '\r\n Se Fusiona a San Lino clave 0164.',
#  '\r\n Localidad rehabilitada.\r\n Cambio de nombre de localidad.',
#  ' \r\nCambio de categoría política de la localidad. ',
#  '\r\nLocalidad rehabilitada. \r\nLocalidad deshabitada',
#  '\r\n Cambio de nombre de localidad. Localidad rehabilitada.\r\nLocalidad deshabitada.',
#  '\r\nLocalidad rehabilitada.\r\nCambio de categoría política de la localidad.',
#  '\r\n Cambio de categoría política de la localidad. \r\n',
#  ' \r\nCambio de nombre de localidad. \r\nCambio de categoría política de la localidad.',
#  '\r\nCambio de nombre de localidad.\r\nLocalidad deshabitada. ',
#  '\r\n Cambio de nombre de localidad.\r\n',
#  '\r\n Localidad rehabilitada. \r\n',
#  '\r\nLocalidad deshabitada. \r\n',
#  ' \r\nLocalidad rehabilitada.\r\nLocalidad deshabitada.',
#  '\r\nBaja de la localidad.',
#  '\r\nCambio de Categoría Política.\r\nLey Orgánica Municipal.\r\n27 de abril de 2011.',
#  '\r\nApartir de este evento la localidad cambia a la clave 03 002 0437.',
#  '\r\nCambio de nombre de la localidad.\r\nLocalidad deshabitada.',
#  '\r\nCambio de nombre de localidad.\r\n Localidad deshabitada.',
#  ' \r\n Cambio de nombre de localidad.',
#  '\r\nA Partir de este evento la localidad Cambia a la clave 1007.',
#  '\r\nCambio de nombre de localidad. \r\nCambio de categoría política de la localidad.\r\n',
#  '\r\n Cambnio de nombre de localidad. Localidad deshabitada.',
#  '\r\nCambio de categoría política. ',
#  ' \r\nCambio de nombre de localidad. \r\n',
#  ' \r\nLocalidad rehabilitada. Localidad  deshabitada. Cambio de nombre de la localidad.',
#  '\r\n Localidad rehabilitada. Cambio de nombre de localidad.\r\nLocalidad deshabitada.',
#  '\r\nCambio de nombre de Localidad. \r\nBaja de localidad.',
#  '\r\nLocalidad rehabilitada.\r\nCambio de nombre de localidad.\r\n Localidad deshabitada.',
#  '\r\nLocalidad rehabilitada.\r\n Localidad deshabitada.',
#  '\r\n Localidad rehabilitada.\r\nLocalidad deshabitada.',
#  '\r\n Cambio de nombre de localidad.  Localidad deshabitada.',
#  '\r\n Cambio de nombre de localidad.\r\nBaja de localidad.',
#  '\r\nA partir de este evento la localidad cambia a la clave 03 002 0401.',
#  '\r\nBaja de localidad.\r\nSe conurbó a La Paz (0001).',
#  '\r\nBaja de localidad.\r\n.',
#  '\r\nCambio de nombre de localidad. \r\n',
#  '\r\nA partir de este evento la localidad cambia a la clave 08 0005.\r\nCambio de nombre de localidad.',
#  '\r\n  Localidad Rehabilitada.',
#  '\r\nCensó con la localidad El Porvenir 1ro.',
#  '\r\nLocalidad Rehabiitada. Cambio de nombre de localidad.',
#  '\r\nCambio de nombre de localidad.\r\nCambio de categoría política de localidad.',
#  '\r\nCambio de nombre de localidad.\r\nLocalidad rehabilitada.\r\nLocalidad deshabitada.',
#  '\r\n Localidad deshabitada. \r\nCambio de categoría política de la localidad.\r\n',
#  '\r\nCambio de categoría política de la localidad. ',
#  '\r\n Cambio de nombre de localidad.\r\nBaja de Localidad.',
#  '\r\n Localidad deshabitada.\r\nLocalidad rehabilitada.',
#  '\r\nLocalidad Rehabilitada.\r\nCambio de nombre de localidad.\r\nLocalidad deshabitada.',
#  '\r\nCambio de nombre de localidad .                .',
#  ' \r\nCambio de nombre de Localidad. ',
#  '\r\nCambio de categoría política de la localidad. Localidad deshabitada.',
#  '\r\nActualización Geoestadística del 25 de mayo 2021. \r\n Se conurba a Todos Santos (0003).\r\n',
#  ' \r\nLocalidad rehabilitada.\r\n Localidad deshabitada.',
#  ' \r\nLocalidad rehabilitada.\r\n',
#  '\r\nLocalidad rehabilitada.\r\nCambio de categoría política de la localidad. \r\nLocalidad deshabitada.',
#  ' \r\nCambio de nombre de  localidad.',
#  '\r\nLocalidad rehabilitada. \r\nViene del municipio La Paz.',
#  '\r\nLocalidad rehabilitada..\r\n Localidad deshabitada.',
#  ' Cambio de nombre de localidad.  Localidad rehabilitada.',
#  '\r\nLocalidad rehabilitada. \r\nCambio de nombre de localidad.',
#  '\r\nLocalidad deshabitada.\r\nCensó con Rancho Guadalupe.',
#  '\r\n Cambio de nombre de localidad.\r\nLocalidad deshabitada.',
#  '\r\n Cambio de nombre de la localidad.\r\nLocalidad deshabitada.',
#  '\r\nCambio  de nombre de la localidad.\r\nLocalidad deshabitada.',
#  '\r\n Cambio de nombre de localidad. \r\nLocalidad deshabitada.',
#  ' Cambio de nombre localidad.',
#  '\r\nCambio de nombre de localidad,.',
#  ' \r\nCambio de nombre de localidad. \r\nLocalidad deshabitada.',
#  '\r\nCambio de nombre localidad.  \r\nLocalidad deshabitada.',
#  '\r\nCambio de categoría política de la localidad.\r\nCambio de nombre de la localidad.',
#  '\r\n Cambio de nombre localidad.\r\nLocalidad deshabitada.',
#  ' \r\n Cambio de nombre de localidad.  ',
#  '\r\n Cambio de nombre de localidad.  ',
#  '\r\nBaja de localidad.\r\nSe da de baja la localidad 0092 y la información referenciada a ésta, se distribuye en.\r\nlas siguientes nuevas localidades para el C. P. y V. 1990 (2242, 1978, 1997, 1994, 0812, 1981, 1979, 1980, 1974, 1995).',
#  '\r\n Cambio de nombre de localidad.\r\nCambio de Categoría Política.\r\nLey Orgánica Municipal.\r\n27 de abril de 2011.',
#  '\r\nCambio de nombre de localidad. \r\nLocalidad rehabilitada.',
#  '\r\nActualización Geoestadística del 25 de mayo 2021. \r\n Se conurba a San José del Cabo (0001).\r\n\r\n',
#  ' Localidad rehabilitada.',
#  '\r\nCambio de nombre de localidad.  \r\n',
#  '\r\n Baja de localidad.\r\n Se da de baja la localidad 0069 y la información referenciada a ésta, se distribuye.\r\nen las siguientes nuevas localidades para el C. P. y V. 1990 (1876, 1929, 1906, 1931, 1903,.\r\n1907, 1908, 1877, 1904, 1874, 1928).',
#  '\r\nCambio de nombre de la localidad.\r\n Localidad deshabitada.',
#  ' Cambio de nombre de localidad. ',
#  '\r\nLocalidad deshabitada. Cambio de nombre de localidad.',
#  ' \r\nLocalidad deshabitada.\r\nCambio de nombre de localidad.',
#  '\r\n Localidad rehabilitada. Localidad deshabitada.',
#  ' \r\nLocalidad deshabitada. ',
#  '\r\n Cambio de nombre de localidad.\r\n Localidad deshabitada.',
#  '\r\nCambio de categoría política la localidad.',
#  '\r\nlocalidad deshabitada.',
#  '\r\nCambio de nombre de localidad.\r\n Localidad deshabitada.\r\n',
#  ' Baja de localidad. ',
#  '\r\n Cambio de nombre de la localidad.\r\n',
#  ' \r\n Cambio de nombre de la localidad.\r\nCambio de categoría política de la localidad.',
#  '\r\n  Cambio de nombre de la localidad.\r\nCambio de categoría política de la localidad. ',
#  '\r\n Cambio de nombre de la localidad.\r\n\r\n',
#  '\r\n \r\n',
#  '\r\nLocalidad deshabitada.\r\nCenso en El Rancho de San Evaristo.',
#  '\r\nLocalidad rehabilitada. ',
#  '\r\nLocalidad deshabitada. Cambio de nombre de localidad. ',
#  '\r\nCambio de nombre de localidad. Localidad rehabilitada.',
#  '\r\nCambio de nombre de localidad, \r\nBaja de localidad.',
#  '\r\n  Cambio de nombre de localidad. ',
#  '\r\nCambio de categoría política de la localidad. \r\n Localidad deshabitada.',
#  ' \r\nCambio de categoría política de la localidad.  \r\n',
#  ' \r\nSe erige en municipio. \r\nViene del municipio Todos Santos.',
#  '\r\n  Cambio de nombre de localidad. \r\nLocalidad deshabitada.',
#  ' Cambio de nombre de localidad. \r\nLocalidad deshabitada.',
#  ' \r\nBaja de localidad. Cambio de nombre de localidad.',
#  '\r\nLocalidad deshabitada.\r\nCambio de nombre de localidad.\r\n\r\n',
#  '\r\nBaja de localidad.\r\nSe da de baja la localidad 0171 y la información referenciada a ésta, se distribuye.\r\nen las siguientes nuevas localidades para el C. P. y V. 1990 (1949, 1934, 1189, 1884, 1990, 1991, 1942, 1988).',
#  '\r\n Cambio de nombre de localidad. Baja de localidad.\r\nSe da de baja la localidad 0179 y la información referenciada a ésta, se distribuye en las.\r\nsiguientes nuevas localidades para el C. P. y V. 1990 (1820, 1819, 1771, 1785, 1784, 1814, 1817, 1816,.\r\n1790, 1831, 0829, 1832, 1811, 1844, 1846, 1845, 1792, 1791, 1794, 1793, 1847, 1797, 1821, 1788, 1798, 1840,.\r\n1842, 1838, 1839, 1745, 1746, 1703, 1704, 1786, 1744, 1705, 1706, 1772, 1707, 1795, 0783, 1825, 0811, 1747).',
#  '\r\n Cambio de nombre de localidad. \r\n',
#  '\r\n Cambio de nombre localidad.',
#  '\r\nBaja de localidad.\r\nSe conurbo a la Ciudad de La Paz.',
#  ' \r\n \r\n',
#  '\r\nLocalidad rehabilitada.\r\nLocalidad deshabitada.\r\nCambio de nombre de localidad',
#  '\r\nCambio de nombre de localidad.\r\nCambio de categoría política.\r\nLocalidad deshabitada.',
#  '\r\n Cambio de nombre de localidad.\r\n ',
#  '\r\n Cambio de nombre de localidad.\r\n Cambio de categoría de política de la localidad. ',
#  ' \r\nCambio de nombre de localidad. \r\n\r\n',
#  ' \r\nCambio de nombre de localidad. \r\nCambio de categoría política de la localidad. \r\nDecreto No. 62 de la Ley Orgánica Municipal Reglamentaria del titulo Octavo Constitucional. 31 de diciembre 1976.',
#  '\r\nCambio de nombre de localidad.\r\nLocalidad deshabitada..\r\n',
#  ' \r\nCambio de nombre de localidad.\r\nCambio de categoría política de la localidad.\r\n',
#  ' \r\nCambio de nombre de localidad.  ',
#  ' \r\nCambio de categoría política de la localidad. \r\nDecreto No. 62 de la Ley Orgánica Municipal Reglamentaria del titulo Octavo Constitucional. 31 de diciembre 1976.',
#  '\r\nCambio de nombre de localidad. \r\n\r\n',
#  ' \r\nCambio de categoría política de la localidad. \r\nDecreto No. 62 de la Ley Orgánica Municipal Reglamentaria del titulo Octavo Constitucional. 31 de diciembre 1976..',
#  '\r\nCambio de nombre de localidad. \r\nLocalidad deshabitada.\r\n\r\n',
#  '\r\nCambio de nombre de localidad.\r\nLocalidad deshabitada..\r\n\r\n',
#  '\r\n  Cambio de nombre de localidad.\r\n',
#  '\r\nActualización Geoestadística del 25 de mayo 2021. \r\n Se conurba a San José del Cabo (0001).\r\n',
#  '\r\nCambio de nombre de localidad\r\nLocalidad deshabitada.',
#  '\r\n Cambio de nombre de localidad. \r\n\r\n',
#  '\r\n Cambio de Categoria Política.',
#  ' \r\n\r\n ',
#  '\r\nCambio de nombre de localidad.\r\nViene del municipio La Paz. ',
#  '\r\nCambio de nombre de localidad.\r\nCambio de categoría política de la localidad. ',
#  '\r\nCambio de nombre de la localidad.\r\nCambio de categoría política de la localidad.',
#  '\r\n Cambio de nombre de localidad. Cambio de Categoría Política.\r\nLey Orgánica Municipal. 27 de abril de 2011.',
#  '\r\n Localidad rehabilitada. \r\nCambio de nombre de localidad. ',
#  ' \r\nCambio de nombre de localidad.\r\n  \r\n',
#  '\r\ncambio de nombre de localidad.',
#  '\r\nSe conurba a la Ciudad de Cabo San Lucas (0054).',
#  '\r\n  Cambio de Nombre de localidad.',
#  '\r\n Localidad rehabilitada.\r\n',
#  '\r\n Cambio de nombre de localidad.\r\n\r\n ',
#  '\r\nCambio de categoría política de la localidad.\r\nLocalidad deshabitada.',
#  '\r\n Cambio de nombre de Localidad, Localidad deshabitada.',
#  '\r\nSe conurba a Colonia del Sol con clave de localidad 0753.',
#  '\r\n\r\n ',
#  '  \r\nCambio de nombre de localidad. \r\n',
#  ' \r\nCambio de nombre de localidad. \r\n \r\n',
#  '\r\nCammbio de nombre de la localidad.\r\nLocalidad deshabitada.',
#  ' \r\nCambio de nombre de la localidad.\r\n',
#  '  \r\nCambio de nombre de localidad.  \r\n',
#  '\r\n Cambio de nombre de localidad. \r\nCambio de categoría política de la localidad. \r\nDecreto No. 62 de la Ley Orgánica Municipal Reglamentaria del titulo Octavo Constitucional. 31 de diciembre de 1976.',
#  '\r\n Localidad deshabitada',
#  '\r\n Cambio de categoría política de la localidad. \r\nDecreto No. 62 de la Ley Orgánica Municipal Reglamentaria del titulo Octavo Constitucional. 31 de diciembre de 1976.',
#  ' \r\nCambio de nombre de localidad.\r\n ',
#  '\r\nBaja de localidad.\r\nMisma localidad que la 0697.',
#  '\r\nBaja de localidad.\r\nSe conurbó a la La Paz (0001)',
#  ' \r\nCambio de nombre de localidad.\r\n \r\n',
#  '\r\nCambio de nombre de localidad. \r\nSe conurbó a la localidad Todos Santos clave 0003.',
#  '\r\n Cambio de nombre localidad. \r\nLocalidad deshabitada.',
#  '\r\n Cambio de nombre localidad. Localidad deshabitada.',
#  '\r\nCambio de nombre localidad. ',
#  ' \r\n Localidad deshabitada.',
#  '  \r\n\r\n',
#  '\r\nLocalidad Rehabilitada.\r\nCambio de nombre de localidad.',
#  ...]

# %%
#puramente_censal.value_counts()
otros.value_counts()
# Out:
# Censo de 2020.
# Localidad deshabitada.               86232
# Conteo de 2005.
# Localidad deshabitada.              72883
# Censo de 2010.
# Localidad deshabitada.               71913
# Censo de 2000.
# Localidad deshabitada.               50078
# Conteo de 1995.
# Localidad deshabitada.              44475
#                                                      ...
# Censo de 1970.
# Hasta este evento estuvo regis...        1
# Conteo de 1995.
# Viene del municipio Ciudad Va...        1
# Censo de 1990.
# Se censó con la localidad La C...        1
# Decreto No. 225 del 2 de diciembre de 1994.
# ...        1
# Censo de 2010.
# Viene del municipio Villa de C...        1
# Name: ORI_MODIF, Length: 68770, dtype: Int64
